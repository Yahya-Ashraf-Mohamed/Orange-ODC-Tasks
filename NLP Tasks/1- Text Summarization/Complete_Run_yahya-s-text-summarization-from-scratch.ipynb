# %%
import os
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import re
import spacy
from spacy.tokenizer import Tokenizer
nlp = spacy.load('en_core_web_sm')
tokenizer = nlp.tokenizer

# %%
# Custom Dataset class
class CustomDataset(Dataset):
    def __init__(self, source_texts, summary_texts, vocab):
        self.source_texts = source_texts
        self.summary_texts = summary_texts
        self.vocab = vocab

    def __len__(self):
        return len(self.source_texts)

    def __getitem__(self, idx):
        source_text = self.source_texts[idx]
        summary_text = self.summary_texts[idx]
        source_tensor = torch.tensor([self.vocab.get(token, 0) for token in source_text], dtype=torch.long)
        summary_tensor = torch.tensor([self.vocab.get(token, 0) for token in summary_text], dtype=torch.long)
        return source_tensor, summary_tensor

# %% [markdown]
# # This part was taken from another notebook uses the same dataset
# ## Just readding the data

# %%
def create_dataframe(source_text_path, target_text_path):
    txt_files_source = [file for file in os.listdir(source_text_path) if file.endswith('.txt')]
    txt_files_target = [file for file in os.listdir(target_text_path) if file.endswith('.txt')]
    df = pd.DataFrame(columns=['headlines', 'text'])
    for source, target in zip(txt_files_source, txt_files_target):
        assert source == target
        source_file_path = os.path.join(source_text_path, source)
        target_file_path = os.path.join(target_text_path, target)
        with open(source_file_path, 'r', encoding='latin-1') as file:
            source_text = file.read()
        with open(target_file_path, 'r', encoding='latin-1') as file:
            target_text = file.read()
        df.loc[len(df.index)] = [source_text, target_text]
    return df

# %% [markdown]
# # Trying to solve Craching problem!
# # and protect my self from out of memory problems

# %%
def save_checkpoint(state, filename='weights.pth.tar'):
    print('Saving weights-->')
    torch.save(state, filename)

def load_checkpoint(checkpoint, model, optim):
    print('Loading weights-->')
    model.load_state_dict(checkpoint['state_dict'])
    optim.load_state_dict(checkpoint['optimizer'])

# %% [markdown]
# # Just start with one dataframe for now
# ## it is not big but it will work fine

# %%
# Load datasets
df1 = create_dataframe("/kaggle/input/bbc-news-summary/BBC News Summary/News Articles/business", 
                       "/kaggle/input/bbc-news-summary/BBC News Summary/Summaries/business")
df2 = create_dataframe("/kaggle/input/bbc-news-summary/BBC News Summary/News Articles/entertainment", 
                       "/kaggle/input/bbc-news-summary/BBC News Summary/Summaries/entertainment")
df3 = create_dataframe("/kaggle/input/bbc-news-summary/BBC News Summary/News Articles/politics", 
                       "/kaggle/input/bbc-news-summary/BBC News Summary/Summaries/politics")
df4 = create_dataframe("/kaggle/input/bbc-news-summary/BBC News Summary/News Articles/sport", 
                      "/kaggle/input/bbc-news-summary/BBC News Summary/Summaries/sport")
df5 = create_dataframe("/kaggle/input/bbc-news-summary/BBC News Summary/News Articles/tech", 
                      "/kaggle/input/bbc-news-summary/BBC News Summary/Summaries/tech")

# Combine data into a single DataFrame
df = pd.concat([df1,df2,df3,df4],ignore_index=True)

# %% [markdown]
# # Data Cleanning
# ### Just copied these words from teh internet

# %%
contraction_mapping = {
    "ain't": "is not", "aren't": "are not", "can't": "cannot",
    "'cause": "because", "could've": "could have", "couldn't": "could not",
    "didn't": "did not", "doesn't": "does not", "don't": "do not",
    "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
    "he'd": "he would", "he'll": "he will", "he's": "he is",
    "how'd": "how did", "how'll": "how will", "how's": "how is",
    "I'd": "I would", "I'll": "I will", "I'm": "I am",
    "isn't": "is not", "it'd": "it would", "it's": "it is",
    "let's": "let us", "ma'am": "madam", "mightn't": "might not",
    "mustn't": "must not", "needn't": "need not", "shan't": "shall not",
    "she'd": "she would", "she's": "she is", "shouldn't": "should not",
    "that's": "that is", "there's": "there is", "they're": "they are",
    "we're": "we are", "won't": "will not", "wouldn't": "would not",
    "y'all": "you all", "you're": "you are"
}


stop_words = set([
    "a", "about", "above", "after", "again", "against", "all", "am", "an",
    "and", "any", "are", "aren't", "as", "at", "be", "because", "been", 
    "before", "being", "below", "between", "both", "but", "by", "can't", 
    "cannot", "could", "couldn't", "did", "didn't", "do", "does", "doesn't", 
    "doing", "don't", "down", "during", "each", "few", "for", "from", "further", 
    "had", "hadn't", "has", "hasn't", "have", "haven't", "he", "he'd", 
    "he'll", "he's", "her", "here", "here's", "hers", "herself", "him", 
    "himself", "his", "how", "how's", "i", "i'd", "i'll", "i'm", "i've", 
    "if", "in", "into", "is", "isn't", "it", "it's", "its", "itself", 
    "just", "ll", "m", "ma", "me", "might", "mightn't", "more", "most", 
    "must", "mustn't", "my", "myself", "need", "needn't", "no", "nor", 
    "not", "now", "o", "of", "off", "on", "once", "only", "or", "other", 
    "our", "ours", "ourselves", "out", "over", "own", "re", "s", "same", 
    "shan't", "she", "she'd", "she'll", "she's", "should", "shouldn't", 
    "so", "some", "such", "t", "than", "that", "that's", "the", "their", 
    "theirs", "them", "themselves", "then", "there", "there's", "these", 
    "they", "they'd", "they'll", "they're", "they've", "this", "those", 
    "through", "to", "too", "under", "until", "up", "ve", "very", "was", 
    "wasn't", "we", "we'd", "we'll", "we're", "we've", "were", "weren't", 
    "what", "what's", "when", "where", "where's", "which", "while", "who", 
    "who's", "whom", "why", "why's", "will", "with", "won't", "would", 
    "wouldn't", "y", "you", "you'd", "you'll", "you're", "you've", "your", 
    "yours", "yourself", "yourselves"
])

# %% [markdown]
# # the same Cleanner I used in the privious projects

# %%
def text_cleaner(text):
    newString = text.lower()
    newString = newString.replace('"', "'")
    newString = re.sub(r'\([^)]*\)', '', newString)
    newString = re.sub('"', '', newString)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b", "", newString)
    newString = re.sub("[^a-zA-Z]", " ", newString) 
    tokens = [w for w in newString.split() if not w in stop_words]
    return " ".join(tokens)

# %% [markdown]
# # Train-Test Split

# %%
# Split into train and test sets
df = df.rename(columns={"headlines": "source_text", "text": "summary_text"})
X, Y = df["source_text"], df["summary_text"]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
train_df = pd.DataFrame({'source_text': X_train, 'summary_text': Y_train})
test_df = pd.DataFrame({'source_text': X_test, 'summary_text': Y_test})

# Preprocess the DataFrame
train_df['source_text'] = train_df['source_text'].apply(lambda x: [token.text.lower() for token in tokenizer(text_cleaner(x))])
train_df['summary_text'] = train_df['summary_text'].apply(lambda x: [token.text.lower() for token in tokenizer(text_cleaner(x))])
test_df['source_text'] = test_df['source_text'].apply(lambda x: [token.text.lower() for token in tokenizer(text_cleaner(x))])
test_df['summary_text'] = test_df['summary_text'].apply(lambda x: [token.text.lower() for token in tokenizer(text_cleaner(x))])

# %% [markdown]
# ### Create my vocabulary from the training dataset that maps each token to a unique integer index.

# %%
# Build vocabularies
all_tokens = train_df['source_text'].tolist() + train_df['summary_text'].tolist()
vocab = {word: idx for idx, word in enumerate(set(token for tokens in all_tokens for token in tokens))}

# %% [markdown]
# # Multi-Head Attention Layer
# ### this is the multi-head attention mechanism used in the Transformer architecture. Nothing new in this code

# %%
# Define the Multi-Head Attention layer
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, n_heads):
        super(MultiHeadAttention, self).__init__()
        self.d_model = d_model
        self.n_heads = n_heads
        self.depth = d_model // n_heads
        self.wq = nn.Linear(d_model, d_model)
        self.wk = nn.Linear(d_model, d_model)
        self.wv = nn.Linear(d_model, d_model)
        self.dense = nn.Linear(d_model, d_model)

    def split_heads(self, x, batch_size):
        x = x.view(batch_size, -1, self.n_heads, self.depth)
        return x.permute(0, 2, 1, 3)  # (batch_size, n_heads, seq_length, depth)

    def forward(self, query, key, value):
        batch_size = query.size(0)
        query = self.split_heads(self.wq(query), batch_size)
        key = self.split_heads(self.wk(key), batch_size)
        value = self.split_heads(self.wv(value), batch_size)

        # Scaled Dot-Product Attention
        matmul_qk = torch.matmul(query, key.transpose(-1, -2))
        dk = query.size(-1)
        scaled_attention_logits = matmul_qk / (dk ** 0.5)
        attention_weights = F.softmax(scaled_attention_logits, dim=-1)

        output = torch.matmul(attention_weights, value)
        output = output.permute(0, 2, 1, 3).contiguous().view(batch_size, -1, self.d_model)
        return self.dense(output)

# %% [markdown]
# # I will use Transformer including the encoder and decoder layers.

# %%
# Define the Transformer model
class Transformer(nn.Module):
    def __init__(self, vocab_size, d_model, n_heads, n_layers, d_ff, max_seq_length, dropout):
        super(Transformer, self).__init__()
        self.encoder = nn.Embedding(vocab_size, d_model)
        self.decoder = nn.Embedding(vocab_size, d_model)
        self.attention = MultiHeadAttention(d_model, n_heads)
        self.ffn = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.ReLU(),
            nn.Linear(d_ff, d_model)
        )
        self.dropout = nn.Dropout(dropout)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.n_layers = n_layers
        
        # Add a linear layer to project to vocab size
        self.output_layer = nn.Linear(d_model, vocab_size)

    def forward(self, src, tgt):
        # Encoder
        enc_output = self.encoder(src)
        enc_output = self.dropout(enc_output)

        # Decoder
        dec_output = self.decoder(tgt)
        dec_output = self.dropout(dec_output)

        for _ in range(self.n_layers):
            attn_output = self.attention(dec_output, enc_output, enc_output)
            dec_output = self.norm1(dec_output + attn_output)
            ffn_output = self.ffn(dec_output)
            dec_output = self.norm2(dec_output + ffn_output)

        # Project the output to vocab size
        output = self.output_layer(dec_output)  # Now this has shape [batch_size, seq_len, vocab_size]
        
        return output

# %% [markdown]
# ## Just tring to solve the length problem

# %%
# Pad source and target batches
def collate_fn(batch):
    source_batch, target_batch = zip(*batch)
    source_batch = torch.nn.utils.rnn.pad_sequence(source_batch, batch_first=True, padding_value=0)
    target_batch = torch.nn.utils.rnn.pad_sequence(target_batch, batch_first=True, padding_value=0)
    return source_batch, target_batch

# %% [markdown]
# # Note do not change the Hyperparameters espicialy the bach size as this chan exceed the memory and may crash

# %%
# This is my Hyperparameters
batch_size = 16
d_model = 256
num_heads = 8
num_layers = 6
d_ff = 512
max_seq_length = 100
dropout = 0.1
learning_rate = 0.001
num_epochs = 500

# %% [markdown]
# ### Just to make sure Kaggel works on the GPU

# %%
# Define the device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Using", device)
# Out:
# Using cuda

# %% [markdown]
# ## Creat the dataset and Initialize my transformer

# %%
# Create Dataset and DataLoader
train_dataset = CustomDataset(train_df['source_text'].tolist(), train_df['summary_text'].tolist(), vocab)
test_dataset = CustomDataset(test_df['source_text'].tolist(), test_df['summary_text'].tolist(), vocab)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

# Initialize the model
model = Transformer(len(vocab), d_model, num_heads, num_layers, d_ff, max_seq_length, dropout).to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

accumulation_steps = 2

# %%
print(model)
# Out:
# Transformer(
#   (encoder): Embedding(21936, 256)
#   (decoder): Embedding(21936, 256)
#   (attention): MultiHeadAttention(
#     (wq): Linear(in_features=256, out_features=256, bias=True)
#     (wk): Linear(in_features=256, out_features=256, bias=True)
#     (wv): Linear(in_features=256, out_features=256, bias=True)
#     (dense): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (ffn): Sequential(
#     (0): Linear(in_features=256, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=256, bias=True)
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   (output_layer): Linear(in_features=256, out_features=21936, bias=True)
# )

# %% [markdown]
# ## Training Loop

# %%
def check_accuracy(output, labels):
    _, predpos = output.max(1)
    num_samples = len(labels)
    num_correct = (predpos == labels).sum()
    return (num_correct / num_samples) * 100

# %%
for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    total_accuracy = 0
    num_batches = 0

    for i, (src, tgt) in enumerate(train_loader):
        src, tgt = src.to(device), tgt.to(device)
        optimizer.zero_grad()

        output = model(src, tgt[:, :-1])
        loss = F.cross_entropy(output.view(-1, len(vocab)), tgt[:, 1:].reshape(-1))
        loss = loss / accumulation_steps  # Scale the loss
        loss.backward()

        if (i + 1) % accumulation_steps == 0:
            optimizer.step()

        total_loss += loss.item()
        num_batches += 1

        # Calc. accuracy
        accuracy = check_accuracy(output.view(-1, len(vocab)), tgt[:, 1:].reshape(-1))
        total_accuracy += accuracy

        # Print progress every 10 batches
        if (i + 1) % 10 == 0:
            print(f"Epoch [{epoch + 1}/{num_epochs}], Step [{i + 1}/{len(train_loader)}], Loss: {loss.item():.4f}, Accuracy: {accuracy:.2f}%")

    avg_loss = total_loss / num_batches
    avg_accuracy = total_accuracy / num_batches
    print(f"Epoch [{epoch + 1}/{num_epochs}] Average Loss: {avg_loss:.4f}, Average Accuracy: {avg_accuracy:.2f}%")

    # Save model checkpoint at the end of each epoch
    # Just to avoid the close of the terminal in kaggel
    save_checkpoint({'state_dict': model.state_dict(), 'optimizer': optimizer.state_dict()})
# Out:
# Epoch [1/500], Step [10/92], Loss: 2.1850, Accuracy: 63.29%
# Epoch [1/500], Step [20/92], Loss: 2.8270, Accuracy: 44.47%
# Epoch [1/500], Step [30/92], Loss: 2.4604, Accuracy: 46.42%
# Epoch [1/500], Step [40/92], Loss: 2.2616, Accuracy: 49.17%
# Epoch [1/500], Step [50/92], Loss: 2.0914, Accuracy: 51.28%
# Epoch [1/500], Step [60/92], Loss: 2.2665, Accuracy: 49.05%
# Epoch [1/500], Step [70/92], Loss: 2.7724, Accuracy: 37.62%
# Epoch [1/500], Step [80/92], Loss: 2.6285, Accuracy: 39.11%
# Epoch [1/500], Step [90/92], Loss: 2.8932, Accuracy: 34.28%
# Epoch [1/500] Average Loss: 2.3905, Average Accuracy: 49.06%
# Saving weights-->
# Epoch [2/500], Step [10/92], Loss: 1.9835, Accuracy: 53.70%
# Epoch [2/500], Step [20/92], Loss: 1.1010, Accuracy: 74.60%
# Epoch [2/500], Step [30/92], Loss: 1.9590, Accuracy: 53.93%
# Epoch [2/500], Step [40/92], Loss: 2.4101, Accuracy: 44.36%
# Epoch [2/500], Step [50/92], Loss: 2.3423, Accuracy: 46.27%
# Epoch [2/500], Step [60/92], Loss: 2.2965, Accuracy: 46.79%
# Epoch [2/500], Step [70/92], Loss: 2.7425, Accuracy: 36.56%
# Epoch [2/500], Step [80/92], Loss: 2.2949, Accuracy: 46.20%
# Epoch [2/500], Step [90/92], Loss: 1.8586, Accuracy: 56.78%
# Epoch [2/500] Average Loss: 2.0983, Average Accuracy: 51.19%
# Saving weights-->
# Epoch [3/500], Step [10/92], Loss: 2.6940, Accuracy: 35.82%
# Epoch [3/500], Step [20/92], Loss: 2.1795, Accuracy: 48.14%
# Epoch [3/500], Step [30/92], Loss: 1.4429, Accuracy: 66.12%
# Epoch [3/500], Step [40/92], Loss: 2.4814, Accuracy: 42.77%
# Epoch [3/500], Step [50/92], Loss: 1.1864, Accuracy: 72.21%
# Epoch [3/500], Step [60/92], Loss: 2.3065, Accuracy: 46.15%
# Epoch [3/500], Step [70/92], Loss: 1.8531, Accuracy: 56.39%
# Epoch [3/500], Step [80/92], Loss: 2.2608, Accuracy: 46.47%
# Epoch [3/500], Step [90/92], Loss: 1.8734, Accuracy: 55.04%
# Epoch [3/500] Average Loss: 2.0950, Average Accuracy: 50.73%
# Saving weights-->
# Epoch [4/500], Step [10/92], Loss: 2.5470, Accuracy: 37.50%
# Epoch [4/500], Step [20/92], Loss: 2.0034, Accuracy: 52.69%
# Epoch [4/500], Step [30/92], Loss: 2.0831, Accuracy: 51.48%
# Epoch [4/500], Step [40/92], Loss: 1.7412, Accuracy: 58.79%
# Epoch [4/500], Step [50/92], Loss: 2.4188, Accuracy: 42.55%
# Epoch [4/500], Step [60/92], Loss: 2.1226, Accuracy: 49.81%
# Epoch [4/500], Step [70/92], Loss: 0.7552, Accuracy: 81.69%
# Epoch [4/500], Step [80/92], Loss: 1.5698, Accuracy: 62.14%
# Epoch [4/500], Step [90/92], Loss: 2.6531, Accuracy: 35.79%
# Epoch [4/500] Average Loss: 2.0403, Average Accuracy: 51.03%
# Saving weights-->
# Epoch [5/500], Step [10/92], Loss: 2.0021, Accuracy: 51.73%
# Epoch [5/500], Step [20/92], Loss: 1.9959, Accuracy: 50.04%
# Epoch [5/500], Step [30/92], Loss: 2.3049, Accuracy: 45.31%
# Epoch [5/500], Step [40/92], Loss: 1.9065, Accuracy: 53.11%
# Epoch [5/500], Step [50/92], Loss: 2.3218, Accuracy: 43.95%
# Epoch [5/500], Step [60/92], Loss: 2.7294, Accuracy: 31.55%
# Epoch [5/500], Step [70/92], Loss: 1.9553, Accuracy: 52.60%
# Epoch [5/500], Step [80/92], Loss: 2.2342, Accuracy: 43.31%
# Epoch [5/500], Step [90/92], Loss: 1.1880, Accuracy: 69.57%
# Epoch [5/500] Average Loss: 2.0124, Average Accuracy: 50.49%
# Saving weights-->
# Epoch [6/500], Step [10/92], Loss: 1.9792, Accuracy: 50.83%
# Epoch [6/500], Step [20/92], Loss: 2.2696, Accuracy: 41.80%
# Epoch [6/500], Step [30/92], Loss: 1.5753, Accuracy: 61.06%
# Epoch [6/500], Step [40/92], Loss: 2.5452, Accuracy: 35.80%
# Epoch [6/500], Step [50/92], Loss: 1.7352, Accuracy: 57.39%
# Epoch [6/500], Step [60/92], Loss: 2.2734, Accuracy: 44.27%
# Epoch [6/500], Step [70/92], Loss: 1.7488, Accuracy: 56.58%
# Epoch [6/500], Step [80/92], Loss: 1.4645, Accuracy: 62.90%
# Epoch [6/500], Step [90/92], Loss: 2.0999, Accuracy: 46.81%
# Epoch [6/500] Average Loss: 1.9024, Average Accuracy: 51.88%
# Saving weights-->
# Epoch [7/500], Step [10/92], Loss: 2.2439, Accuracy: 41.70%
# Epoch [7/500], Step [20/92], Loss: 1.5884, Accuracy: 57.76%
# Epoch [7/500], Step [30/92], Loss: 1.9402, Accuracy: 50.93%
# Epoch [7/500], Step [40/92], Loss: 1.9581, Accuracy: 49.49%
# Epoch [7/500], Step [50/92], Loss: 1.5881, Accuracy: 59.17%
# Epoch [7/500], Step [60/92], Loss: 2.1612, Accuracy: 45.11%
# Epoch [7/500], Step [70/92], Loss: 1.4396, Accuracy: 62.91%
# Epoch [7/500], Step [80/92], Loss: 1.6292, Accuracy: 57.55%
# Epoch [7/500], Step [90/92], Loss: 1.8729, Accuracy: 49.80%
# Epoch [7/500] Average Loss: 1.8262, Average Accuracy: 52.45%
# Saving weights-->
# Epoch [8/500], Step [10/92], Loss: 0.5598, Accuracy: 85.83%
# Epoch [8/500], Step [20/92], Loss: 1.9256, Accuracy: 47.30%
# Epoch [8/500], Step [30/92], Loss: 1.6018, Accuracy: 57.49%
# Epoch [8/500], Step [40/92], Loss: 2.5040, Accuracy: 31.81%
# Epoch [8/500], Step [50/92], Loss: 2.1157, Accuracy: 43.44%
# Epoch [8/500], Step [60/92], Loss: 1.7902, Accuracy: 50.45%
# Epoch [8/500], Step [70/92], Loss: 1.7966, Accuracy: 53.03%
# Epoch [8/500], Step [80/92], Loss: 1.9731, Accuracy: 46.48%
# Epoch [8/500], Step [90/92], Loss: 1.3571, Accuracy: 61.36%
# Epoch [8/500] Average Loss: 1.7365, Average Accuracy: 53.11%
# Saving weights-->
# Epoch [9/500], Step [10/92], Loss: 1.8267, Accuracy: 48.69%
# Epoch [9/500], Step [20/92], Loss: 1.6769, Accuracy: 53.43%
# Epoch [9/500], Step [30/92], Loss: 1.6064, Accuracy: 53.78%
# Epoch [9/500], Step [40/92], Loss: 1.9745, Accuracy: 44.41%
# Epoch [9/500], Step [50/92], Loss: 1.8266, Accuracy: 51.85%
# Epoch [9/500], Step [60/92], Loss: 2.0113, Accuracy: 44.20%
# Epoch [9/500], Step [70/92], Loss: 1.1041, Accuracy: 68.44%
# Epoch [9/500], Step [80/92], Loss: 1.8348, Accuracy: 50.10%
# Epoch [9/500], Step [90/92], Loss: 1.8423, Accuracy: 48.67%
# Epoch [9/500] Average Loss: 1.6528, Average Accuracy: 54.00%
# Saving weights-->
# Epoch [10/500], Step [10/92], Loss: 1.4600, Accuracy: 56.55%
# Epoch [10/500], Step [20/92], Loss: 1.8751, Accuracy: 47.75%
# Epoch [10/500], Step [30/92], Loss: 1.8414, Accuracy: 46.03%
# Epoch [10/500], Step [40/92], Loss: 1.4903, Accuracy: 56.13%
# Epoch [10/500], Step [50/92], Loss: 1.5003, Accuracy: 54.00%
# Epoch [10/500], Step [60/92], Loss: 1.7063, Accuracy: 48.37%
# Epoch [10/500], Step [70/92], Loss: 1.3959, Accuracy: 60.82%
# Epoch [10/500], Step [80/92], Loss: 1.7211, Accuracy: 52.76%
# Epoch [10/500], Step [90/92], Loss: 1.3173, Accuracy: 63.76%
# Epoch [10/500] Average Loss: 1.5866, Average Accuracy: 54.23%
# Saving weights-->
# Epoch [11/500], Step [10/92], Loss: 1.5884, Accuracy: 54.25%
# Epoch [11/500], Step [20/92], Loss: 1.3247, Accuracy: 60.07%
# Epoch [11/500], Step [30/92], Loss: 1.4094, Accuracy: 57.00%
# Epoch [11/500], Step [40/92], Loss: 1.9096, Accuracy: 44.28%
# Epoch [11/500], Step [50/92], Loss: 1.0930, Accuracy: 69.33%
# Epoch [11/500], Step [60/92], Loss: 1.6911, Accuracy: 47.87%
# Epoch [11/500], Step [70/92], Loss: 1.5714, Accuracy: 54.75%
# Epoch [11/500], Step [80/92], Loss: 1.1958, Accuracy: 64.91%
# Epoch [11/500], Step [90/92], Loss: 1.7259, Accuracy: 48.16%
# Epoch [11/500] Average Loss: 1.4881, Average Accuracy: 55.79%
# Saving weights-->
# Epoch [12/500], Step [10/92], Loss: 1.3845, Accuracy: 58.95%
# Epoch [12/500], Step [20/92], Loss: 0.6292, Accuracy: 80.61%
# Epoch [12/500], Step [30/92], Loss: 1.7146, Accuracy: 48.44%
# Epoch [12/500], Step [40/92], Loss: 1.2370, Accuracy: 62.41%
# Epoch [12/500], Step [50/92], Loss: 1.2851, Accuracy: 59.99%
# Epoch [12/500], Step [60/92], Loss: 1.2442, Accuracy: 61.39%
# Epoch [12/500], Step [70/92], Loss: 1.3577, Accuracy: 58.85%
# Epoch [12/500], Step [80/92], Loss: 1.5412, Accuracy: 52.54%
# Epoch [12/500], Step [90/92], Loss: 1.3375, Accuracy: 58.98%
# Epoch [12/500] Average Loss: 1.4434, Average Accuracy: 55.87%
# Saving weights-->
# Epoch [13/500], Step [10/92], Loss: 1.7756, Accuracy: 43.14%
# Epoch [13/500], Step [20/92], Loss: 0.5834, Accuracy: 82.25%
# Epoch [13/500], Step [30/92], Loss: 1.7328, Accuracy: 44.94%
# Epoch [13/500], Step [40/92], Loss: 1.3099, Accuracy: 58.05%
# Epoch [13/500], Step [50/92], Loss: 1.0679, Accuracy: 67.60%
# Epoch [13/500], Step [60/92], Loss: 1.2081, Accuracy: 62.56%
# Epoch [13/500], Step [70/92], Loss: 0.8873, Accuracy: 72.33%
# Epoch [13/500], Step [80/92], Loss: 1.4875, Accuracy: 52.98%
# Epoch [13/500], Step [90/92], Loss: 1.7257, Accuracy: 48.30%
# Epoch [13/500] Average Loss: 1.3476, Average Accuracy: 57.80%
# Saving weights-->
# Epoch [14/500], Step [10/92], Loss: 1.1616, Accuracy: 61.84%
# Epoch [14/500], Step [20/92], Loss: 1.4367, Accuracy: 54.09%
# Epoch [14/500], Step [30/92], Loss: 1.3953, Accuracy: 54.83%
# Epoch [14/500], Step [40/92], Loss: 1.1288, Accuracy: 62.24%
# Epoch [14/500], Step [50/92], Loss: 1.1165, Accuracy: 61.36%
# Epoch [14/500], Step [60/92], Loss: 1.4199, Accuracy: 54.95%
# Epoch [14/500], Step [70/92], Loss: 1.2012, Accuracy: 61.48%
# Epoch [14/500], Step [80/92], Loss: 1.6859, Accuracy: 46.44%
# Epoch [14/500], Step [90/92], Loss: 1.7427, Accuracy: 45.30%
# Epoch [14/500] Average Loss: 1.2532, Average Accuracy: 59.69%
# Saving weights-->
# Epoch [15/500], Step [10/92], Loss: 1.0625, Accuracy: 65.36%
# Epoch [15/500], Step [20/92], Loss: 1.3758, Accuracy: 52.81%
# Epoch [15/500], Step [30/92], Loss: 1.3628, Accuracy: 56.71%
# Epoch [15/500], Step [40/92], Loss: 1.4715, Accuracy: 52.64%
# Epoch [15/500], Step [50/92], Loss: 0.8819, Accuracy: 71.89%
# Epoch [15/500], Step [60/92], Loss: 1.2894, Accuracy: 57.41%
# Epoch [15/500], Step [70/92], Loss: 1.3403, Accuracy: 54.70%
# Epoch [15/500], Step [80/92], Loss: 0.4551, Accuracy: 86.47%
# Epoch [15/500], Step [90/92], Loss: 0.9966, Accuracy: 65.75%
# Epoch [15/500] Average Loss: 1.1961, Average Accuracy: 60.73%
# Saving weights-->
# Epoch [16/500], Step [10/92], Loss: 1.2091, Accuracy: 59.26%
# Epoch [16/500], Step [20/92], Loss: 1.2821, Accuracy: 56.61%
# Epoch [16/500], Step [30/92], Loss: 1.4373, Accuracy: 51.09%
# Epoch [16/500], Step [40/92], Loss: 0.8718, Accuracy: 69.82%
# Epoch [16/500], Step [50/92], Loss: 0.4928, Accuracy: 84.26%
# Epoch [16/500], Step [60/92], Loss: 1.2871, Accuracy: 55.39%
# Epoch [16/500], Step [70/92], Loss: 1.0943, Accuracy: 62.15%
# Epoch [16/500], Step [80/92], Loss: 1.1311, Accuracy: 62.85%
# Epoch [16/500], Step [90/92], Loss: 1.0018, Accuracy: 66.40%
# Epoch [16/500] Average Loss: 1.1260, Average Accuracy: 62.24%
# Saving weights-->
# Epoch [17/500], Step [10/92], Loss: 0.8641, Accuracy: 70.72%
# Epoch [17/500], Step [20/92], Loss: 0.9461, Accuracy: 66.90%
# Epoch [17/500], Step [30/92], Loss: 1.2405, Accuracy: 57.18%
# Epoch [17/500], Step [40/92], Loss: 0.7048, Accuracy: 77.16%
# Epoch [17/500], Step [50/92], Loss: 1.1281, Accuracy: 61.98%
# Epoch [17/500], Step [60/92], Loss: 1.3412, Accuracy: 53.35%
# Epoch [17/500], Step [70/92], Loss: 1.1197, Accuracy: 62.05%
# Epoch [17/500], Step [80/92], Loss: 1.2201, Accuracy: 56.75%
# Epoch [17/500], Step [90/92], Loss: 0.8907, Accuracy: 70.46%
# Epoch [17/500] Average Loss: 1.0930, Average Accuracy: 62.72%
# Saving weights-->
# Epoch [18/500], Step [10/92], Loss: 1.0764, Accuracy: 61.30%
# Epoch [18/500], Step [20/92], Loss: 1.1082, Accuracy: 61.33%
# Epoch [18/500], Step [30/92], Loss: 1.2102, Accuracy: 58.06%
# Epoch [18/500], Step [40/92], Loss: 0.9965, Accuracy: 65.49%
# Epoch [18/500], Step [50/92], Loss: 0.9281, Accuracy: 67.96%
# Epoch [18/500], Step [60/92], Loss: 1.1815, Accuracy: 60.08%
# Epoch [18/500], Step [70/92], Loss: 1.0642, Accuracy: 63.70%
# Epoch [18/500], Step [80/92], Loss: 0.9072, Accuracy: 68.39%
# Epoch [18/500], Step [90/92], Loss: 1.2949, Accuracy: 55.29%
# Epoch [18/500] Average Loss: 1.0177, Average Accuracy: 64.62%
# Saving weights-->
# Epoch [19/500], Step [10/92], Loss: 1.0818, Accuracy: 62.02%
# Epoch [19/500], Step [20/92], Loss: 1.0805, Accuracy: 60.59%
# Epoch [19/500], Step [30/92], Loss: 1.0234, Accuracy: 63.58%
# Epoch [19/500], Step [40/92], Loss: 1.2830, Accuracy: 55.53%
# Epoch [19/500], Step [50/92], Loss: 0.9257, Accuracy: 66.36%
# Epoch [19/500], Step [60/92], Loss: 0.9988, Accuracy: 65.95%
# Epoch [19/500], Step [70/92], Loss: 1.0211, Accuracy: 63.07%
# Epoch [19/500], Step [80/92], Loss: 1.3049, Accuracy: 53.50%
# Epoch [19/500], Step [90/92], Loss: 0.9666, Accuracy: 64.91%
# Epoch [19/500] Average Loss: 0.9805, Average Accuracy: 65.31%
# Saving weights-->
# Epoch [20/500], Step [10/92], Loss: 0.8001, Accuracy: 70.71%
# Epoch [20/500], Step [20/92], Loss: 0.3468, Accuracy: 89.27%
# Epoch [20/500], Step [30/92], Loss: 0.9953, Accuracy: 64.37%
# Epoch [20/500], Step [40/92], Loss: 0.8598, Accuracy: 69.35%
# Epoch [20/500], Step [50/92], Loss: 1.0577, Accuracy: 61.28%
# Epoch [20/500], Step [60/92], Loss: 0.7766, Accuracy: 73.81%
# Epoch [20/500], Step [70/92], Loss: 1.0437, Accuracy: 63.65%
# Epoch [20/500], Step [80/92], Loss: 1.2803, Accuracy: 52.55%
# Epoch [20/500], Step [90/92], Loss: 1.0351, Accuracy: 62.65%
# Epoch [20/500] Average Loss: 0.9337, Average Accuracy: 66.48%
# Saving weights-->
# Epoch [21/500], Step [10/92], Loss: 0.8754, Accuracy: 68.13%
# Epoch [21/500], Step [20/92], Loss: 1.1218, Accuracy: 60.65%
# Epoch [21/500], Step [30/92], Loss: 1.0102, Accuracy: 62.30%
# Epoch [21/500], Step [40/92], Loss: 0.8623, Accuracy: 68.79%
# Epoch [21/500], Step [50/92], Loss: 0.7634, Accuracy: 71.63%
# Epoch [21/500], Step [60/92], Loss: 0.8960, Accuracy: 67.40%
# Epoch [21/500], Step [70/92], Loss: 0.6765, Accuracy: 74.83%
# Epoch [21/500], Step [80/92], Loss: 0.3814, Accuracy: 87.44%
# Epoch [21/500], Step [90/92], Loss: 0.6673, Accuracy: 76.23%
# Epoch [21/500] Average Loss: 0.8685, Average Accuracy: 68.32%
# Saving weights-->
# Epoch [22/500], Step [10/92], Loss: 1.1106, Accuracy: 60.40%
# Epoch [22/500], Step [20/92], Loss: 1.0270, Accuracy: 61.64%
# Epoch [22/500], Step [30/92], Loss: 0.6882, Accuracy: 74.38%
# Epoch [22/500], Step [40/92], Loss: 0.8448, Accuracy: 67.85%
# Epoch [22/500], Step [50/92], Loss: 0.4856, Accuracy: 82.07%
# Epoch [22/500], Step [60/92], Loss: 0.9759, Accuracy: 64.99%
# Epoch [22/500], Step [70/92], Loss: 0.8443, Accuracy: 68.34%
# Epoch [22/500], Step [80/92], Loss: 0.8377, Accuracy: 68.79%
# Epoch [22/500], Step [90/92], Loss: 0.7688, Accuracy: 70.41%
# Epoch [22/500] Average Loss: 0.8457, Average Accuracy: 68.49%
# Saving weights-->
# Epoch [23/500], Step [10/92], Loss: 0.7985, Accuracy: 69.45%
# Epoch [23/500], Step [20/92], Loss: 0.9171, Accuracy: 64.40%
# Epoch [23/500], Step [30/92], Loss: 0.6102, Accuracy: 76.80%
# Epoch [23/500], Step [40/92], Loss: 0.8052, Accuracy: 70.21%
# Epoch [23/500], Step [50/92], Loss: 0.7077, Accuracy: 73.93%
# Epoch [23/500], Step [60/92], Loss: 0.8583, Accuracy: 67.60%
# Epoch [23/500], Step [70/92], Loss: 0.4115, Accuracy: 85.43%
# Epoch [23/500], Step [80/92], Loss: 0.7436, Accuracy: 71.08%
# Epoch [23/500], Step [90/92], Loss: 0.5082, Accuracy: 80.72%
# Epoch [23/500] Average Loss: 0.7929, Average Accuracy: 70.08%
# Saving weights-->
# Epoch [24/500], Step [10/92], Loss: 0.3816, Accuracy: 86.77%
# Epoch [24/500], Step [20/92], Loss: 0.7552, Accuracy: 70.99%
# Epoch [24/500], Step [30/92], Loss: 0.6917, Accuracy: 73.00%
# Epoch [24/500], Step [40/92], Loss: 1.0735, Accuracy: 61.80%
# Epoch [24/500], Step [50/92], Loss: 0.7653, Accuracy: 68.67%
# Epoch [24/500], Step [60/92], Loss: 0.9058, Accuracy: 63.94%
# Epoch [24/500], Step [70/92], Loss: 0.8854, Accuracy: 66.38%
# Epoch [24/500], Step [80/92], Loss: 0.4349, Accuracy: 84.59%
# Epoch [24/500], Step [90/92], Loss: 0.5005, Accuracy: 81.06%
# Epoch [24/500] Average Loss: 0.7700, Average Accuracy: 70.49%
# Saving weights-->
# Epoch [25/500], Step [10/92], Loss: 0.8957, Accuracy: 65.65%
# Epoch [25/500], Step [20/92], Loss: 0.6485, Accuracy: 74.44%
# Epoch [25/500], Step [30/92], Loss: 0.6637, Accuracy: 74.52%
# Epoch [25/500], Step [40/92], Loss: 0.5738, Accuracy: 77.69%
# Epoch [25/500], Step [50/92], Loss: 0.9190, Accuracy: 64.29%
# Epoch [25/500], Step [60/92], Loss: 0.8043, Accuracy: 68.58%
# Epoch [25/500], Step [70/92], Loss: 0.8077, Accuracy: 67.85%
# Epoch [25/500], Step [80/92], Loss: 0.7567, Accuracy: 70.77%
# Epoch [25/500], Step [90/92], Loss: 0.6845, Accuracy: 73.68%
# Epoch [25/500] Average Loss: 0.7338, Average Accuracy: 71.40%
# Saving weights-->
# Epoch [26/500], Step [10/92], Loss: 0.6738, Accuracy: 72.07%
# Epoch [26/500], Step [20/92], Loss: 0.7389, Accuracy: 69.90%
# Epoch [26/500], Step [30/92], Loss: 0.7670, Accuracy: 70.28%
# Epoch [26/500], Step [40/92], Loss: 0.5770, Accuracy: 76.48%
# Epoch [26/500], Step [50/92], Loss: 0.6708, Accuracy: 73.76%
# Epoch [26/500], Step [60/92], Loss: 0.5897, Accuracy: 77.50%
# Epoch [26/500], Step [70/92], Loss: 0.7762, Accuracy: 68.01%
# Epoch [26/500], Step [80/92], Loss: 0.7369, Accuracy: 72.24%
# Epoch [26/500], Step [90/92], Loss: 0.7486, Accuracy: 71.35%
# Epoch [26/500] Average Loss: 0.7171, Average Accuracy: 71.71%
# Saving weights-->
# Epoch [27/500], Step [10/92], Loss: 0.3575, Accuracy: 87.11%
# Epoch [27/500], Step [20/92], Loss: 0.8712, Accuracy: 65.51%
# Epoch [27/500], Step [30/92], Loss: 0.6485, Accuracy: 75.38%
# Epoch [27/500], Step [40/92], Loss: 0.7244, Accuracy: 70.48%
# Epoch [27/500], Step [50/92], Loss: 0.8276, Accuracy: 66.52%
# Epoch [27/500], Step [60/92], Loss: 0.6328, Accuracy: 75.18%
# Epoch [27/500], Step [70/92], Loss: 0.8191, Accuracy: 67.68%
# Epoch [27/500], Step [80/92], Loss: 0.7432, Accuracy: 70.45%
# Epoch [27/500], Step [90/92], Loss: 0.7238, Accuracy: 71.96%
# Epoch [27/500] Average Loss: 0.6902, Average Accuracy: 72.47%
# Saving weights-->
# Epoch [28/500], Step [10/92], Loss: 0.6242, Accuracy: 75.38%
# Epoch [28/500], Step [20/92], Loss: 0.6583, Accuracy: 73.80%
# Epoch [28/500], Step [30/92], Loss: 0.5139, Accuracy: 78.78%
# Epoch [28/500], Step [40/92], Loss: 0.6755, Accuracy: 72.47%
# Epoch [28/500], Step [50/92], Loss: 0.7351, Accuracy: 71.41%
# Epoch [28/500], Step [60/92], Loss: 0.7251, Accuracy: 71.23%
# Epoch [28/500], Step [70/92], Loss: 0.3413, Accuracy: 89.24%
# Epoch [28/500], Step [80/92], Loss: 0.5340, Accuracy: 77.01%
# Epoch [28/500], Step [90/92], Loss: 0.4167, Accuracy: 84.71%
# Epoch [28/500] Average Loss: 0.6673, Average Accuracy: 72.91%
# Saving weights-->
# Epoch [29/500], Step [10/92], Loss: 0.5239, Accuracy: 78.52%
# Epoch [29/500], Step [20/92], Loss: 0.4905, Accuracy: 79.97%
# Epoch [29/500], Step [30/92], Loss: 0.8636, Accuracy: 65.36%
# Epoch [29/500], Step [40/92], Loss: 0.5896, Accuracy: 76.06%
# Epoch [29/500], Step [50/92], Loss: 0.6485, Accuracy: 72.51%
# Epoch [29/500], Step [60/92], Loss: 0.5979, Accuracy: 74.84%
# Epoch [29/500], Step [70/92], Loss: 0.6338, Accuracy: 74.31%
# Epoch [29/500], Step [80/92], Loss: 0.6190, Accuracy: 74.08%
# Epoch [29/500], Step [90/92], Loss: 0.5259, Accuracy: 78.73%
# Epoch [29/500] Average Loss: 0.6379, Average Accuracy: 73.89%
# Saving weights-->
# Epoch [30/500], Step [10/92], Loss: 0.6943, Accuracy: 71.70%
# Epoch [30/500], Step [20/92], Loss: 0.5953, Accuracy: 75.59%
# Epoch [30/500], Step [30/92], Loss: 0.7299, Accuracy: 68.80%
# Epoch [30/500], Step [40/92], Loss: 0.3953, Accuracy: 84.48%
# Epoch [30/500], Step [50/92], Loss: 0.4557, Accuracy: 80.49%
# Epoch [30/500], Step [60/92], Loss: 0.7151, Accuracy: 70.49%
# Epoch [30/500], Step [70/92], Loss: 0.5586, Accuracy: 76.56%
# Epoch [30/500], Step [80/92], Loss: 0.6358, Accuracy: 73.61%
# Epoch [30/500], Step [90/92], Loss: 0.6385, Accuracy: 72.03%
# Epoch [30/500] Average Loss: 0.6098, Average Accuracy: 74.73%
# Saving weights-->
# Epoch [31/500], Step [10/92], Loss: 0.4923, Accuracy: 79.49%
# Epoch [31/500], Step [20/92], Loss: 0.6183, Accuracy: 73.94%
# Epoch [31/500], Step [30/92], Loss: 0.6098, Accuracy: 75.04%
# Epoch [31/500], Step [40/92], Loss: 0.5540, Accuracy: 75.77%
# Epoch [31/500], Step [50/92], Loss: 0.7012, Accuracy: 72.87%
# Epoch [31/500], Step [60/92], Loss: 0.6991, Accuracy: 69.63%
# Epoch [31/500], Step [70/92], Loss: 0.6334, Accuracy: 73.33%
# Epoch [31/500], Step [80/92], Loss: 0.4215, Accuracy: 81.64%
# Epoch [31/500], Step [90/92], Loss: 0.6534, Accuracy: 72.35%
# Epoch [31/500] Average Loss: 0.6061, Average Accuracy: 74.52%
# Saving weights-->
# Epoch [32/500], Step [10/92], Loss: 0.6017, Accuracy: 73.50%
# Epoch [32/500], Step [20/92], Loss: 0.5951, Accuracy: 75.10%
# Epoch [32/500], Step [30/92], Loss: 0.5507, Accuracy: 75.99%
# Epoch [32/500], Step [40/92], Loss: 0.5033, Accuracy: 78.67%
# Epoch [32/500], Step [50/92], Loss: 0.3568, Accuracy: 84.96%
# Epoch [32/500], Step [60/92], Loss: 0.6165, Accuracy: 72.89%
# Epoch [32/500], Step [70/92], Loss: 0.6004, Accuracy: 74.57%
# Epoch [32/500], Step [80/92], Loss: 0.4965, Accuracy: 79.17%
# Epoch [32/500], Step [90/92], Loss: 0.7777, Accuracy: 69.37%
# Epoch [32/500] Average Loss: 0.5814, Average Accuracy: 75.41%
# Saving weights-->
# Epoch [33/500], Step [10/92], Loss: 0.5561, Accuracy: 76.83%
# Epoch [33/500], Step [20/92], Loss: 0.4697, Accuracy: 78.03%
# Epoch [33/500], Step [30/92], Loss: 0.4853, Accuracy: 79.49%
# Epoch [33/500], Step [40/92], Loss: 0.4907, Accuracy: 79.51%
# Epoch [33/500], Step [50/92], Loss: 0.6412, Accuracy: 73.96%
# Epoch [33/500], Step [60/92], Loss: 0.5141, Accuracy: 78.26%
# Epoch [33/500], Step [70/92], Loss: 0.6226, Accuracy: 72.30%
# Epoch [33/500], Step [80/92], Loss: 0.6687, Accuracy: 70.16%
# Epoch [33/500], Step [90/92], Loss: 0.5484, Accuracy: 76.11%
# Epoch [33/500] Average Loss: 0.5568, Average Accuracy: 76.01%
# Saving weights-->
# Epoch [34/500], Step [10/92], Loss: 0.4149, Accuracy: 82.09%
# Epoch [34/500], Step [20/92], Loss: 0.5796, Accuracy: 75.17%
# Epoch [34/500], Step [30/92], Loss: 0.5002, Accuracy: 77.96%
# Epoch [34/500], Step [40/92], Loss: 0.6818, Accuracy: 70.16%
# Epoch [34/500], Step [50/92], Loss: 0.5697, Accuracy: 75.11%
# Epoch [34/500], Step [60/92], Loss: 0.5934, Accuracy: 73.77%
# Epoch [34/500], Step [70/92], Loss: 0.5571, Accuracy: 75.35%
# Epoch [34/500], Step [80/92], Loss: 0.8018, Accuracy: 65.02%
# Epoch [34/500], Step [90/92], Loss: 0.5740, Accuracy: 75.87%
# Epoch [34/500] Average Loss: 0.5451, Average Accuracy: 76.42%
# Saving weights-->
# Epoch [35/500], Step [10/92], Loss: 0.7106, Accuracy: 69.24%
# Epoch [35/500], Step [20/92], Loss: 0.6121, Accuracy: 73.48%
# Epoch [35/500], Step [30/92], Loss: 0.4941, Accuracy: 77.66%
# Epoch [35/500], Step [40/92], Loss: 0.2521, Accuracy: 91.27%
# Epoch [35/500], Step [50/92], Loss: 0.3522, Accuracy: 83.90%
# Epoch [35/500], Step [60/92], Loss: 0.6048, Accuracy: 72.44%
# Epoch [35/500], Step [70/92], Loss: 0.3355, Accuracy: 84.22%
# Epoch [35/500], Step [80/92], Loss: 0.6798, Accuracy: 70.51%
# Epoch [35/500], Step [90/92], Loss: 0.6189, Accuracy: 73.42%
# Epoch [35/500] Average Loss: 0.5264, Average Accuracy: 77.00%
# Saving weights-->
# Epoch [36/500], Step [10/92], Loss: 0.5188, Accuracy: 77.11%
# Epoch [36/500], Step [20/92], Loss: 0.5693, Accuracy: 74.47%
# Epoch [36/500], Step [30/92], Loss: 0.5258, Accuracy: 76.77%
# Epoch [36/500], Step [40/92], Loss: 0.4089, Accuracy: 82.01%
# Epoch [36/500], Step [50/92], Loss: 0.5920, Accuracy: 74.51%
# Epoch [36/500], Step [60/92], Loss: 0.2993, Accuracy: 89.34%
# Epoch [36/500], Step [70/92], Loss: 0.6524, Accuracy: 70.62%
# Epoch [36/500], Step [80/92], Loss: 0.3847, Accuracy: 83.12%
# Epoch [36/500], Step [90/92], Loss: 0.5132, Accuracy: 77.75%
# Epoch [36/500] Average Loss: 0.5125, Average Accuracy: 77.25%
# Saving weights-->
# Epoch [37/500], Step [10/92], Loss: 0.5123, Accuracy: 75.77%
# Epoch [37/500], Step [20/92], Loss: 0.2901, Accuracy: 89.53%
# Epoch [37/500], Step [30/92], Loss: 0.4514, Accuracy: 77.72%
# Epoch [37/500], Step [40/92], Loss: 0.3367, Accuracy: 85.93%
# Epoch [37/500], Step [50/92], Loss: 0.5978, Accuracy: 73.81%
# Epoch [37/500], Step [60/92], Loss: 0.3183, Accuracy: 85.17%
# Epoch [37/500], Step [70/92], Loss: 0.5208, Accuracy: 75.51%
# Epoch [37/500], Step [80/92], Loss: 0.5152, Accuracy: 76.11%
# Epoch [37/500], Step [90/92], Loss: 0.5865, Accuracy: 74.00%
# Epoch [37/500] Average Loss: 0.4897, Average Accuracy: 78.07%
# Saving weights-->
# Epoch [38/500], Step [10/92], Loss: 0.5142, Accuracy: 76.98%
# Epoch [38/500], Step [20/92], Loss: 0.5627, Accuracy: 76.05%
# Epoch [38/500], Step [30/92], Loss: 0.4890, Accuracy: 79.14%
# Epoch [38/500], Step [40/92], Loss: 0.3989, Accuracy: 82.24%
# Epoch [38/500], Step [50/92], Loss: 0.3144, Accuracy: 84.88%
# Epoch [38/500], Step [60/92], Loss: 0.4709, Accuracy: 79.73%
# Epoch [38/500], Step [70/92], Loss: 0.4203, Accuracy: 80.03%
# Epoch [38/500], Step [80/92], Loss: 0.3743, Accuracy: 82.44%
# Epoch [38/500], Step [90/92], Loss: 0.4396, Accuracy: 80.51%
# Epoch [38/500] Average Loss: 0.4716, Average Accuracy: 78.70%
# Saving weights-->
# Epoch [39/500], Step [10/92], Loss: 0.4854, Accuracy: 77.34%
# Epoch [39/500], Step [20/92], Loss: 0.2686, Accuracy: 90.23%
# Epoch [39/500], Step [30/92], Loss: 0.4316, Accuracy: 80.01%
# Epoch [39/500], Step [40/92], Loss: 0.5231, Accuracy: 75.94%
# Epoch [39/500], Step [50/92], Loss: 0.4103, Accuracy: 80.44%
# Epoch [39/500], Step [60/92], Loss: 0.3173, Accuracy: 86.40%
# Epoch [39/500], Step [70/92], Loss: 0.4345, Accuracy: 79.50%
# Epoch [39/500], Step [80/92], Loss: 0.4908, Accuracy: 77.42%
# Epoch [39/500], Step [90/92], Loss: 0.4042, Accuracy: 81.00%
# Epoch [39/500] Average Loss: 0.4579, Average Accuracy: 79.01%
# Saving weights-->
# Epoch [40/500], Step [10/92], Loss: 0.3985, Accuracy: 81.37%
# Epoch [40/500], Step [20/92], Loss: 0.4343, Accuracy: 80.21%
# Epoch [40/500], Step [30/92], Loss: 0.2888, Accuracy: 86.84%
# Epoch [40/500], Step [40/92], Loss: 0.5407, Accuracy: 76.54%
# Epoch [40/500], Step [50/92], Loss: 0.4788, Accuracy: 78.42%
# Epoch [40/500], Step [60/92], Loss: 0.6014, Accuracy: 73.45%
# Epoch [40/500], Step [70/92], Loss: 0.4755, Accuracy: 76.77%
# Epoch [40/500], Step [80/92], Loss: 0.4662, Accuracy: 78.32%
# Epoch [40/500], Step [90/92], Loss: 0.6280, Accuracy: 72.05%
# Epoch [40/500] Average Loss: 0.4441, Average Accuracy: 79.57%
# Saving weights-->
# Epoch [41/500], Step [10/92], Loss: 0.2584, Accuracy: 91.32%
# Epoch [41/500], Step [20/92], Loss: 0.5446, Accuracy: 74.83%
# Epoch [41/500], Step [30/92], Loss: 0.3715, Accuracy: 82.60%
# Epoch [41/500], Step [40/92], Loss: 0.4511, Accuracy: 78.20%
# Epoch [41/500], Step [50/92], Loss: 0.3171, Accuracy: 85.52%
# Epoch [41/500], Step [60/92], Loss: 0.3292, Accuracy: 84.90%
# Epoch [41/500], Step [70/92], Loss: 0.3466, Accuracy: 83.52%
# Epoch [41/500], Step [80/92], Loss: 0.4631, Accuracy: 79.98%
# Epoch [41/500], Step [90/92], Loss: 0.4661, Accuracy: 78.79%
# Epoch [41/500] Average Loss: 0.4481, Average Accuracy: 79.12%
# Saving weights-->
# Epoch [42/500], Step [10/92], Loss: 0.4816, Accuracy: 77.63%
# Epoch [42/500], Step [20/92], Loss: 0.3838, Accuracy: 81.78%
# Epoch [42/500], Step [30/92], Loss: 0.4226, Accuracy: 79.23%
# Epoch [42/500], Step [40/92], Loss: 0.4534, Accuracy: 80.13%
# Epoch [42/500], Step [50/92], Loss: 0.5020, Accuracy: 77.15%
# Epoch [42/500], Step [60/92], Loss: 0.4072, Accuracy: 80.49%
# Epoch [42/500], Step [70/92], Loss: 0.4403, Accuracy: 79.88%
# Epoch [42/500], Step [80/92], Loss: 0.4114, Accuracy: 80.27%
# Epoch [42/500], Step [90/92], Loss: 0.4448, Accuracy: 79.15%
# Epoch [42/500] Average Loss: 0.4297, Average Accuracy: 79.93%
# Saving weights-->
# Epoch [43/500], Step [10/92], Loss: 0.4571, Accuracy: 79.06%
# Epoch [43/500], Step [20/92], Loss: 0.4356, Accuracy: 78.38%
# Epoch [43/500], Step [30/92], Loss: 0.4283, Accuracy: 80.25%
# Epoch [43/500], Step [40/92], Loss: 0.3633, Accuracy: 82.18%
# Epoch [43/500], Step [50/92], Loss: 0.4426, Accuracy: 79.56%
# Epoch [43/500], Step [60/92], Loss: 0.4141, Accuracy: 80.53%
# Epoch [43/500], Step [70/92], Loss: 0.4565, Accuracy: 80.10%
# Epoch [43/500], Step [80/92], Loss: 0.4605, Accuracy: 77.34%
# Epoch [43/500], Step [90/92], Loss: 0.4959, Accuracy: 77.37%
# Epoch [43/500] Average Loss: 0.4237, Average Accuracy: 80.08%
# Saving weights-->
# Epoch [44/500], Step [10/92], Loss: 0.3823, Accuracy: 81.63%
# Epoch [44/500], Step [20/92], Loss: 0.3824, Accuracy: 82.42%
# Epoch [44/500], Step [30/92], Loss: 0.2902, Accuracy: 85.48%
# Epoch [44/500], Step [40/92], Loss: 0.2473, Accuracy: 91.44%
# Epoch [44/500], Step [50/92], Loss: 0.4894, Accuracy: 75.65%
# Epoch [44/500], Step [60/92], Loss: 0.4585, Accuracy: 77.69%
# Epoch [44/500], Step [70/92], Loss: 0.4029, Accuracy: 81.08%
# Epoch [44/500], Step [80/92], Loss: 0.4805, Accuracy: 77.89%
# Epoch [44/500], Step [90/92], Loss: 0.2674, Accuracy: 87.32%
# Epoch [44/500] Average Loss: 0.4073, Average Accuracy: 80.74%
# Saving weights-->
# Epoch [45/500], Step [10/92], Loss: 0.2292, Accuracy: 89.24%
# Epoch [45/500], Step [20/92], Loss: 0.3148, Accuracy: 84.17%
# Epoch [45/500], Step [30/92], Loss: 0.3917, Accuracy: 81.92%
# Epoch [45/500], Step [40/92], Loss: 0.2485, Accuracy: 90.23%
# Epoch [45/500], Step [50/92], Loss: 0.2784, Accuracy: 86.44%
# Epoch [45/500], Step [60/92], Loss: 0.4743, Accuracy: 77.64%
# Epoch [45/500], Step [70/92], Loss: 0.3438, Accuracy: 84.27%
# Epoch [45/500], Step [80/92], Loss: 0.3942, Accuracy: 81.29%
# Epoch [45/500], Step [90/92], Loss: 0.4773, Accuracy: 77.64%
# Epoch [45/500] Average Loss: 0.4062, Average Accuracy: 80.67%
# Saving weights-->
# Epoch [46/500], Step [10/92], Loss: 0.4135, Accuracy: 80.23%
# Epoch [46/500], Step [20/92], Loss: 0.3024, Accuracy: 85.61%
# Epoch [46/500], Step [30/92], Loss: 0.3648, Accuracy: 82.59%
# Epoch [46/500], Step [40/92], Loss: 0.4245, Accuracy: 78.97%
# Epoch [46/500], Step [50/92], Loss: 0.3538, Accuracy: 81.60%
# Epoch [46/500], Step [60/92], Loss: 0.2085, Accuracy: 91.51%
# Epoch [46/500], Step [70/92], Loss: 0.4560, Accuracy: 77.08%
# Epoch [46/500], Step [80/92], Loss: 0.3773, Accuracy: 81.58%
# Epoch [46/500], Step [90/92], Loss: 0.5424, Accuracy: 73.92%
# Epoch [46/500] Average Loss: 0.3927, Average Accuracy: 81.15%
# Saving weights-->
# Epoch [47/500], Step [10/92], Loss: 0.3583, Accuracy: 82.61%
# Epoch [47/500], Step [20/92], Loss: 0.3707, Accuracy: 82.01%
# Epoch [47/500], Step [30/92], Loss: 0.3786, Accuracy: 80.63%
# Epoch [47/500], Step [40/92], Loss: 0.4671, Accuracy: 78.46%
# Epoch [47/500], Step [50/92], Loss: 0.3453, Accuracy: 83.77%
# Epoch [47/500], Step [60/92], Loss: 0.5233, Accuracy: 75.29%
# Epoch [47/500], Step [70/92], Loss: 0.3335, Accuracy: 83.97%
# Epoch [47/500], Step [80/92], Loss: 0.5528, Accuracy: 73.32%
# Epoch [47/500], Step [90/92], Loss: 0.5430, Accuracy: 73.69%
# Epoch [47/500] Average Loss: 0.3825, Average Accuracy: 81.51%
# Saving weights-->
# Epoch [48/500], Step [10/92], Loss: 0.3859, Accuracy: 81.16%
# Epoch [48/500], Step [20/92], Loss: 0.3992, Accuracy: 81.02%
# Epoch [48/500], Step [30/92], Loss: 0.3691, Accuracy: 81.55%
# Epoch [48/500], Step [40/92], Loss: 0.4671, Accuracy: 76.41%
# Epoch [48/500], Step [50/92], Loss: 0.3647, Accuracy: 81.92%
# Epoch [48/500], Step [60/92], Loss: 0.2654, Accuracy: 87.79%
# Epoch [48/500], Step [70/92], Loss: 0.3587, Accuracy: 83.41%
# Epoch [48/500], Step [80/92], Loss: 0.3447, Accuracy: 83.52%
# Epoch [48/500], Step [90/92], Loss: 0.2303, Accuracy: 90.98%
# Epoch [48/500] Average Loss: 0.3804, Average Accuracy: 81.65%
# Saving weights-->
# Epoch [49/500], Step [10/92], Loss: 0.3541, Accuracy: 82.60%
# Epoch [49/500], Step [20/92], Loss: 0.4693, Accuracy: 77.42%
# Epoch [49/500], Step [30/92], Loss: 0.3061, Accuracy: 85.42%
# Epoch [49/500], Step [40/92], Loss: 0.4352, Accuracy: 79.61%
# Epoch [49/500], Step [50/92], Loss: 0.3276, Accuracy: 84.21%
# Epoch [49/500], Step [60/92], Loss: 0.4293, Accuracy: 78.58%
# Epoch [49/500], Step [70/92], Loss: 0.2813, Accuracy: 85.56%
# Epoch [49/500], Step [80/92], Loss: 0.4731, Accuracy: 76.85%
# Epoch [49/500], Step [90/92], Loss: 0.3031, Accuracy: 85.32%
# Epoch [49/500] Average Loss: 0.3677, Average Accuracy: 82.01%
# Saving weights-->
# Epoch [50/500], Step [10/92], Loss: 0.3298, Accuracy: 84.07%
# Epoch [50/500], Step [20/92], Loss: 0.3142, Accuracy: 83.78%
# Epoch [50/500], Step [30/92], Loss: 0.3024, Accuracy: 84.78%
# Epoch [50/500], Step [40/92], Loss: 0.3340, Accuracy: 83.32%
# Epoch [50/500], Step [50/92], Loss: 0.3211, Accuracy: 83.41%
# Epoch [50/500], Step [60/92], Loss: 0.4119, Accuracy: 80.33%
# Epoch [50/500], Step [70/92], Loss: 0.1923, Accuracy: 90.30%
# Epoch [50/500], Step [80/92], Loss: 0.3480, Accuracy: 82.62%
# Epoch [50/500], Step [90/92], Loss: 0.4014, Accuracy: 80.56%
# Epoch [50/500] Average Loss: 0.3565, Average Accuracy: 82.48%
# Saving weights-->
# Epoch [51/500], Step [10/92], Loss: 0.3164, Accuracy: 84.03%
# Epoch [51/500], Step [20/92], Loss: 0.2618, Accuracy: 86.33%
# Epoch [51/500], Step [30/92], Loss: 0.2369, Accuracy: 91.46%
# Epoch [51/500], Step [40/92], Loss: 0.3566, Accuracy: 83.54%
# Epoch [51/500], Step [50/92], Loss: 0.3581, Accuracy: 81.97%
# Epoch [51/500], Step [60/92], Loss: 0.2954, Accuracy: 84.13%
# Epoch [51/500], Step [70/92], Loss: 0.3657, Accuracy: 82.01%
# Epoch [51/500], Step [80/92], Loss: 0.4064, Accuracy: 79.04%
# Epoch [51/500], Step [90/92], Loss: 0.3820, Accuracy: 80.67%
# Epoch [51/500] Average Loss: 0.3435, Average Accuracy: 82.94%
# Saving weights-->
# Epoch [52/500], Step [10/92], Loss: 0.2244, Accuracy: 89.41%
# Epoch [52/500], Step [20/92], Loss: 0.3067, Accuracy: 84.55%
# Epoch [52/500], Step [30/92], Loss: 0.2410, Accuracy: 89.58%
# Epoch [52/500], Step [40/92], Loss: 0.4123, Accuracy: 79.07%
# Epoch [52/500], Step [50/92], Loss: 0.4072, Accuracy: 79.60%
# Epoch [52/500], Step [60/92], Loss: 0.4303, Accuracy: 78.83%
# Epoch [52/500], Step [70/92], Loss: 0.3677, Accuracy: 81.37%
# Epoch [52/500], Step [80/92], Loss: 0.3176, Accuracy: 82.79%
# Epoch [52/500], Step [90/92], Loss: 0.4258, Accuracy: 78.43%
# Epoch [52/500] Average Loss: 0.3408, Average Accuracy: 83.02%
# Saving weights-->
# Epoch [53/500], Step [10/92], Loss: 0.4797, Accuracy: 76.67%
# Epoch [53/500], Step [20/92], Loss: 0.2674, Accuracy: 87.00%
# Epoch [53/500], Step [30/92], Loss: 0.1916, Accuracy: 93.22%
# Epoch [53/500], Step [40/92], Loss: 0.3163, Accuracy: 83.99%
# Epoch [53/500], Step [50/92], Loss: 0.2744, Accuracy: 87.01%
# Epoch [53/500], Step [60/92], Loss: 0.3035, Accuracy: 85.03%
# Epoch [53/500], Step [70/92], Loss: 0.2065, Accuracy: 90.90%
# Epoch [53/500], Step [80/92], Loss: 0.3851, Accuracy: 80.20%
# Epoch [53/500], Step [90/92], Loss: 0.3829, Accuracy: 81.61%
# Epoch [53/500] Average Loss: 0.3427, Average Accuracy: 82.98%
# Saving weights-->
# Epoch [54/500], Step [10/92], Loss: 0.2123, Accuracy: 88.69%
# Epoch [54/500], Step [20/92], Loss: 0.3366, Accuracy: 82.22%
# Epoch [54/500], Step [30/92], Loss: 0.3319, Accuracy: 83.16%
# Epoch [54/500], Step [40/92], Loss: 0.3650, Accuracy: 82.13%
# Epoch [54/500], Step [50/92], Loss: 0.2935, Accuracy: 84.68%
# Epoch [54/500], Step [60/92], Loss: 0.3744, Accuracy: 81.08%
# Epoch [54/500], Step [70/92], Loss: 0.3361, Accuracy: 83.50%
# Epoch [54/500], Step [80/92], Loss: 0.3751, Accuracy: 80.97%
# Epoch [54/500], Step [90/92], Loss: 0.4388, Accuracy: 78.08%
# Epoch [54/500] Average Loss: 0.3361, Average Accuracy: 83.14%
# Saving weights-->
# Epoch [55/500], Step [10/92], Loss: 0.3436, Accuracy: 82.94%
# Epoch [55/500], Step [20/92], Loss: 0.3038, Accuracy: 84.93%
# Epoch [55/500], Step [30/92], Loss: 0.3388, Accuracy: 82.25%
# Epoch [55/500], Step [40/92], Loss: 0.2896, Accuracy: 84.60%
# Epoch [55/500], Step [50/92], Loss: 0.2860, Accuracy: 85.65%
# Epoch [55/500], Step [60/92], Loss: 0.2159, Accuracy: 89.87%
# Epoch [55/500], Step [70/92], Loss: 0.2893, Accuracy: 84.77%
# Epoch [55/500], Step [80/92], Loss: 0.3753, Accuracy: 81.40%
# Epoch [55/500], Step [90/92], Loss: 0.3510, Accuracy: 80.57%
# Epoch [55/500] Average Loss: 0.3217, Average Accuracy: 83.74%
# Saving weights-->
# Epoch [56/500], Step [10/92], Loss: 0.3091, Accuracy: 83.91%
# Epoch [56/500], Step [20/92], Loss: 0.2930, Accuracy: 85.61%
# Epoch [56/500], Step [30/92], Loss: 0.3063, Accuracy: 84.80%
# Epoch [56/500], Step [40/92], Loss: 0.3235, Accuracy: 82.87%
# Epoch [56/500], Step [50/92], Loss: 0.2693, Accuracy: 86.26%
# Epoch [56/500], Step [60/92], Loss: 0.3446, Accuracy: 81.73%
# Epoch [56/500], Step [70/92], Loss: 0.3891, Accuracy: 80.10%
# Epoch [56/500], Step [80/92], Loss: 0.3805, Accuracy: 80.05%
# Epoch [56/500], Step [90/92], Loss: 0.3582, Accuracy: 80.94%
# Epoch [56/500] Average Loss: 0.3136, Average Accuracy: 84.01%
# Saving weights-->
# Epoch [57/500], Step [10/92], Loss: 0.3035, Accuracy: 83.92%
# Epoch [57/500], Step [20/92], Loss: 0.3842, Accuracy: 80.35%
# Epoch [57/500], Step [30/92], Loss: 0.2485, Accuracy: 87.40%
# Epoch [57/500], Step [40/92], Loss: 0.3416, Accuracy: 83.00%
# Epoch [57/500], Step [50/92], Loss: 0.3759, Accuracy: 81.35%
# Epoch [57/500], Step [60/92], Loss: 0.1752, Accuracy: 91.27%
# Epoch [57/500], Step [70/92], Loss: 0.3333, Accuracy: 83.31%
# Epoch [57/500], Step [80/92], Loss: 0.3349, Accuracy: 82.25%
# Epoch [57/500], Step [90/92], Loss: 0.3652, Accuracy: 80.82%
# Epoch [57/500] Average Loss: 0.3324, Average Accuracy: 83.21%
# Saving weights-->
# Epoch [58/500], Step [10/92], Loss: 0.3528, Accuracy: 81.33%
# Epoch [58/500], Step [20/92], Loss: 0.2465, Accuracy: 87.33%
# Epoch [58/500], Step [30/92], Loss: 0.2362, Accuracy: 91.40%
# Epoch [58/500], Step [40/92], Loss: 0.3386, Accuracy: 82.51%
# Epoch [58/500], Step [50/92], Loss: 0.3325, Accuracy: 82.78%
# Epoch [58/500], Step [60/92], Loss: 0.2726, Accuracy: 85.83%
# Epoch [58/500], Step [70/92], Loss: 0.2581, Accuracy: 86.29%
# Epoch [58/500], Step [80/92], Loss: 0.3304, Accuracy: 84.10%
# Epoch [58/500], Step [90/92], Loss: 0.3188, Accuracy: 83.48%
# Epoch [58/500] Average Loss: 0.3084, Average Accuracy: 84.28%
# Saving weights-->
# Epoch [59/500], Step [10/92], Loss: 0.3106, Accuracy: 83.69%
# Epoch [59/500], Step [20/92], Loss: 0.3702, Accuracy: 80.39%
# Epoch [59/500], Step [30/92], Loss: 0.1975, Accuracy: 90.38%
# Epoch [59/500], Step [40/92], Loss: 0.2875, Accuracy: 85.48%
# Epoch [59/500], Step [50/92], Loss: 0.2946, Accuracy: 84.05%
# Epoch [59/500], Step [60/92], Loss: 0.3496, Accuracy: 81.40%
# Epoch [59/500], Step [70/92], Loss: 0.3291, Accuracy: 82.41%
# Epoch [59/500], Step [80/92], Loss: 0.3134, Accuracy: 84.29%
# Epoch [59/500], Step [90/92], Loss: 0.2867, Accuracy: 85.32%
# Epoch [59/500] Average Loss: 0.2963, Average Accuracy: 84.77%
# Saving weights-->
# Epoch [60/500], Step [10/92], Loss: 0.3292, Accuracy: 83.86%
# Epoch [60/500], Step [20/92], Loss: 0.3692, Accuracy: 80.63%
# Epoch [60/500], Step [30/92], Loss: 0.3529, Accuracy: 83.33%
# Epoch [60/500], Step [40/92], Loss: 0.3051, Accuracy: 83.79%
# Epoch [60/500], Step [50/92], Loss: 0.3059, Accuracy: 84.11%
# Epoch [60/500], Step [60/92], Loss: 0.3212, Accuracy: 82.72%
# Epoch [60/500], Step [70/92], Loss: 0.2503, Accuracy: 87.14%
# Epoch [60/500], Step [80/92], Loss: 0.3008, Accuracy: 84.63%
# Epoch [60/500], Step [90/92], Loss: 0.2211, Accuracy: 88.59%
# Epoch [60/500] Average Loss: 0.3055, Average Accuracy: 84.30%
# Saving weights-->
# Epoch [61/500], Step [10/92], Loss: 0.3369, Accuracy: 81.92%
# Epoch [61/500], Step [20/92], Loss: 0.2780, Accuracy: 84.62%
# Epoch [61/500], Step [30/92], Loss: 0.3116, Accuracy: 82.77%
# Epoch [61/500], Step [40/92], Loss: 0.2544, Accuracy: 86.66%
# Epoch [61/500], Step [50/92], Loss: 0.3309, Accuracy: 83.87%
# Epoch [61/500], Step [60/92], Loss: 0.2041, Accuracy: 89.82%
# Epoch [61/500], Step [70/92], Loss: 0.3497, Accuracy: 82.58%
# Epoch [61/500], Step [80/92], Loss: 0.3314, Accuracy: 82.18%
# Epoch [61/500], Step [90/92], Loss: 0.4014, Accuracy: 79.32%
# Epoch [61/500] Average Loss: 0.3046, Average Accuracy: 84.37%
# Saving weights-->
# Epoch [62/500], Step [10/92], Loss: 0.2825, Accuracy: 86.57%
# Epoch [62/500], Step [20/92], Loss: 0.2768, Accuracy: 86.03%
# Epoch [62/500], Step [30/92], Loss: 0.3615, Accuracy: 81.68%
# Epoch [62/500], Step [40/92], Loss: 0.2012, Accuracy: 89.32%
# Epoch [62/500], Step [50/92], Loss: 0.3110, Accuracy: 83.72%
# Epoch [62/500], Step [60/92], Loss: 0.3948, Accuracy: 80.79%
# Epoch [62/500], Step [70/92], Loss: 0.3523, Accuracy: 81.52%
# Epoch [62/500], Step [80/92], Loss: 0.2513, Accuracy: 86.44%
# Epoch [62/500], Step [90/92], Loss: 0.3669, Accuracy: 80.89%
# Epoch [62/500] Average Loss: 0.2875, Average Accuracy: 85.08%
# Saving weights-->
# Epoch [63/500], Step [10/92], Loss: 0.4148, Accuracy: 78.31%
# Epoch [63/500], Step [20/92], Loss: 0.3070, Accuracy: 84.88%
# Epoch [63/500], Step [30/92], Loss: 0.3281, Accuracy: 82.35%
# Epoch [63/500], Step [40/92], Loss: 0.3423, Accuracy: 81.62%
# Epoch [63/500], Step [50/92], Loss: 0.2834, Accuracy: 85.97%
# Epoch [63/500], Step [60/92], Loss: 0.2791, Accuracy: 85.22%
# Epoch [63/500], Step [70/92], Loss: 0.3156, Accuracy: 82.95%
# Epoch [63/500], Step [80/92], Loss: 0.3015, Accuracy: 84.99%
# Epoch [63/500], Step [90/92], Loss: 0.2365, Accuracy: 87.18%
# Epoch [63/500] Average Loss: 0.2913, Average Accuracy: 84.91%
# Saving weights-->
# Epoch [64/500], Step [10/92], Loss: 0.2808, Accuracy: 85.47%
# Epoch [64/500], Step [20/92], Loss: 0.3384, Accuracy: 82.43%
# Epoch [64/500], Step [30/92], Loss: 0.3291, Accuracy: 83.24%
# Epoch [64/500], Step [40/92], Loss: 0.3170, Accuracy: 82.79%
# Epoch [64/500], Step [50/92], Loss: 0.3217, Accuracy: 83.16%
# Epoch [64/500], Step [60/92], Loss: 0.1996, Accuracy: 89.87%
# Epoch [64/500], Step [70/92], Loss: 0.3509, Accuracy: 81.53%
# Epoch [64/500], Step [80/92], Loss: 0.2074, Accuracy: 91.62%
# Epoch [64/500], Step [90/92], Loss: 0.2765, Accuracy: 85.75%
# Epoch [64/500] Average Loss: 0.2958, Average Accuracy: 84.72%
# Saving weights-->
# Epoch [65/500], Step [10/92], Loss: 0.3924, Accuracy: 80.46%
# Epoch [65/500], Step [20/92], Loss: 0.2379, Accuracy: 87.61%
# Epoch [65/500], Step [30/92], Loss: 0.2183, Accuracy: 90.59%
# Epoch [65/500], Step [40/92], Loss: 0.3552, Accuracy: 79.93%
# Epoch [65/500], Step [50/92], Loss: 0.2266, Accuracy: 88.47%
# Epoch [65/500], Step [60/92], Loss: 0.2973, Accuracy: 83.37%
# Epoch [65/500], Step [70/92], Loss: 0.3870, Accuracy: 78.45%
# Epoch [65/500], Step [80/92], Loss: 0.2690, Accuracy: 85.56%
# Epoch [65/500], Step [90/92], Loss: 0.3113, Accuracy: 83.85%
# Epoch [65/500] Average Loss: 0.2887, Average Accuracy: 84.97%
# Saving weights-->
# Epoch [66/500], Step [10/92], Loss: 0.3148, Accuracy: 83.33%
# Epoch [66/500], Step [20/92], Loss: 0.3306, Accuracy: 82.10%
# Epoch [66/500], Step [30/92], Loss: 0.2094, Accuracy: 88.64%
# Epoch [66/500], Step [40/92], Loss: 0.2809, Accuracy: 85.64%
# Epoch [66/500], Step [50/92], Loss: 0.3505, Accuracy: 82.49%
# Epoch [66/500], Step [60/92], Loss: 0.2905, Accuracy: 85.26%
# Epoch [66/500], Step [70/92], Loss: 0.2185, Accuracy: 89.02%
# Epoch [66/500], Step [80/92], Loss: 0.2509, Accuracy: 87.30%
# Epoch [66/500], Step [90/92], Loss: 0.2759, Accuracy: 85.16%
# Epoch [66/500] Average Loss: 0.2803, Average Accuracy: 85.46%
# Saving weights-->
# Epoch [67/500], Step [10/92], Loss: 0.2591, Accuracy: 85.82%
# Epoch [67/500], Step [20/92], Loss: 0.3201, Accuracy: 82.84%
# Epoch [67/500], Step [30/92], Loss: 0.2907, Accuracy: 84.14%
# Epoch [67/500], Step [40/92], Loss: 0.3363, Accuracy: 82.67%
# Epoch [67/500], Step [50/92], Loss: 0.3638, Accuracy: 81.04%
# Epoch [67/500], Step [60/92], Loss: 0.3473, Accuracy: 81.44%
# Epoch [67/500], Step [70/92], Loss: 0.2811, Accuracy: 85.56%
# Epoch [67/500], Step [80/92], Loss: 0.1532, Accuracy: 93.11%
# Epoch [67/500], Step [90/92], Loss: 0.2438, Accuracy: 86.91%
# Epoch [67/500] Average Loss: 0.2771, Average Accuracy: 85.54%
# Saving weights-->
# Epoch [68/500], Step [10/92], Loss: 0.3207, Accuracy: 82.80%
# Epoch [68/500], Step [20/92], Loss: 0.3023, Accuracy: 84.46%
# Epoch [68/500], Step [30/92], Loss: 0.1744, Accuracy: 92.95%
# Epoch [68/500], Step [40/92], Loss: 0.2556, Accuracy: 87.02%
# Epoch [68/500], Step [50/92], Loss: 0.2935, Accuracy: 85.05%
# Epoch [68/500], Step [60/92], Loss: 0.3064, Accuracy: 83.68%
# Epoch [68/500], Step [70/92], Loss: 0.2251, Accuracy: 87.43%
# Epoch [68/500], Step [80/92], Loss: 0.2867, Accuracy: 85.09%
# Epoch [68/500], Step [90/92], Loss: 0.2134, Accuracy: 88.69%
# Epoch [68/500] Average Loss: 0.2748, Average Accuracy: 85.54%
# Saving weights-->
# Epoch [69/500], Step [10/92], Loss: 0.2495, Accuracy: 86.43%
# Epoch [69/500], Step [20/92], Loss: 0.2679, Accuracy: 86.62%
# Epoch [69/500], Step [30/92], Loss: 0.3928, Accuracy: 79.56%
# Epoch [69/500], Step [40/92], Loss: 0.2907, Accuracy: 84.87%
# Epoch [69/500], Step [50/92], Loss: 0.2798, Accuracy: 84.60%
# Epoch [69/500], Step [60/92], Loss: 0.2303, Accuracy: 88.54%
# Epoch [69/500], Step [70/92], Loss: 0.2271, Accuracy: 87.97%
# Epoch [69/500], Step [80/92], Loss: 0.3324, Accuracy: 82.63%
# Epoch [69/500], Step [90/92], Loss: 0.2722, Accuracy: 86.59%
# Epoch [69/500] Average Loss: 0.2937, Average Accuracy: 84.63%
# Saving weights-->
# Epoch [70/500], Step [10/92], Loss: 0.3764, Accuracy: 80.07%
# Epoch [70/500], Step [20/92], Loss: 0.2120, Accuracy: 92.58%
# Epoch [70/500], Step [30/92], Loss: 0.2848, Accuracy: 84.66%
# Epoch [70/500], Step [40/92], Loss: 0.2772, Accuracy: 85.40%
# Epoch [70/500], Step [50/92], Loss: 0.3180, Accuracy: 82.17%
# Epoch [70/500], Step [60/92], Loss: 0.3498, Accuracy: 81.94%
# Epoch [70/500], Step [70/92], Loss: 0.3155, Accuracy: 82.56%
# Epoch [70/500], Step [80/92], Loss: 0.2519, Accuracy: 86.74%
# Epoch [70/500], Step [90/92], Loss: 0.3385, Accuracy: 82.10%
# Epoch [70/500] Average Loss: 0.2830, Average Accuracy: 85.21%
# Saving weights-->
# Epoch [71/500], Step [10/92], Loss: 0.3648, Accuracy: 81.67%
# Epoch [71/500], Step [20/92], Loss: 0.2854, Accuracy: 85.03%
# Epoch [71/500], Step [30/92], Loss: 0.3461, Accuracy: 83.35%
# Epoch [71/500], Step [40/92], Loss: 0.2289, Accuracy: 88.13%
# Epoch [71/500], Step [50/92], Loss: 0.3002, Accuracy: 84.80%
# Epoch [71/500], Step [60/92], Loss: 0.2810, Accuracy: 84.61%
# Epoch [71/500], Step [70/92], Loss: 0.3199, Accuracy: 82.51%
# Epoch [71/500], Step [80/92], Loss: 0.3090, Accuracy: 83.44%
# Epoch [71/500], Step [90/92], Loss: 0.3430, Accuracy: 81.59%
# Epoch [71/500] Average Loss: 0.2831, Average Accuracy: 85.29%
# Saving weights-->
# Epoch [72/500], Step [10/92], Loss: 0.2948, Accuracy: 85.69%
# Epoch [72/500], Step [20/92], Loss: 0.2345, Accuracy: 87.40%
# Epoch [72/500], Step [30/92], Loss: 0.3214, Accuracy: 82.96%
# Epoch [72/500], Step [40/92], Loss: 0.2231, Accuracy: 87.69%
# Epoch [72/500], Step [50/92], Loss: 0.3263, Accuracy: 82.55%
# Epoch [72/500], Step [60/92], Loss: 0.3124, Accuracy: 82.83%
# Epoch [72/500], Step [70/92], Loss: 0.3321, Accuracy: 83.30%
# Epoch [72/500], Step [80/92], Loss: 0.2293, Accuracy: 87.32%
# Epoch [72/500], Step [90/92], Loss: 0.2697, Accuracy: 85.39%
# Epoch [72/500] Average Loss: 0.2730, Average Accuracy: 85.62%
# Saving weights-->
# Epoch [73/500], Step [10/92], Loss: 0.2888, Accuracy: 84.47%
# Epoch [73/500], Step [20/92], Loss: 0.2596, Accuracy: 85.98%
# Epoch [73/500], Step [30/92], Loss: 0.3098, Accuracy: 83.02%
# Epoch [73/500], Step [40/92], Loss: 0.2719, Accuracy: 85.23%
# Epoch [73/500], Step [50/92], Loss: 0.3019, Accuracy: 84.24%
# Epoch [73/500], Step [60/92], Loss: 0.2843, Accuracy: 84.47%
# Epoch [73/500], Step [70/92], Loss: 0.2497, Accuracy: 86.68%
# Epoch [73/500], Step [80/92], Loss: 0.2656, Accuracy: 85.38%
# Epoch [73/500], Step [90/92], Loss: 0.3323, Accuracy: 82.01%
# Epoch [73/500] Average Loss: 0.2692, Average Accuracy: 85.70%
# Saving weights-->
# Epoch [74/500], Step [10/92], Loss: 0.2369, Accuracy: 87.69%
# Epoch [74/500], Step [20/92], Loss: 0.2612, Accuracy: 86.33%
# Epoch [74/500], Step [30/92], Loss: 0.2583, Accuracy: 86.33%
# Epoch [74/500], Step [40/92], Loss: 0.3013, Accuracy: 84.76%
# Epoch [74/500], Step [50/92], Loss: 0.2105, Accuracy: 88.93%
# Epoch [74/500], Step [60/92], Loss: 0.3186, Accuracy: 82.62%
# Epoch [74/500], Step [70/92], Loss: 0.2910, Accuracy: 85.96%
# Epoch [74/500], Step [80/92], Loss: 0.1373, Accuracy: 93.89%
# Epoch [74/500], Step [90/92], Loss: 0.3397, Accuracy: 81.77%
# Epoch [74/500] Average Loss: 0.2640, Average Accuracy: 86.07%
# Saving weights-->
# Epoch [75/500], Step [10/92], Loss: 0.2834, Accuracy: 84.90%
# Epoch [75/500], Step [20/92], Loss: 0.2738, Accuracy: 85.54%
# Epoch [75/500], Step [30/92], Loss: 0.2532, Accuracy: 86.58%
# Epoch [75/500], Step [40/92], Loss: 0.2093, Accuracy: 88.98%
# Epoch [75/500], Step [50/92], Loss: 0.2939, Accuracy: 84.80%
# Epoch [75/500], Step [60/92], Loss: 0.2827, Accuracy: 85.04%
# Epoch [75/500], Step [70/92], Loss: 0.1607, Accuracy: 92.94%
# Epoch [75/500], Step [80/92], Loss: 0.2958, Accuracy: 84.20%
# Epoch [75/500], Step [90/92], Loss: 0.1949, Accuracy: 89.29%
# Epoch [75/500] Average Loss: 0.2613, Average Accuracy: 86.20%
# Saving weights-->
# Epoch [76/500], Step [10/92], Loss: 0.3428, Accuracy: 83.16%
# Epoch [76/500], Step [20/92], Loss: 0.2952, Accuracy: 84.85%
# Epoch [76/500], Step [30/92], Loss: 0.2597, Accuracy: 85.45%
# Epoch [76/500], Step [40/92], Loss: 0.1899, Accuracy: 90.13%
# Epoch [76/500], Step [50/92], Loss: 0.3397, Accuracy: 83.48%
# Epoch [76/500], Step [60/92], Loss: 0.2206, Accuracy: 88.18%
# Epoch [76/500], Step [70/92], Loss: 0.2340, Accuracy: 87.37%
# Epoch [76/500], Step [80/92], Loss: 0.2448, Accuracy: 87.37%
# Epoch [76/500], Step [90/92], Loss: 0.2092, Accuracy: 87.91%
# Epoch [76/500] Average Loss: 0.2581, Average Accuracy: 86.39%
# Saving weights-->
# Epoch [77/500], Step [10/92], Loss: 0.2462, Accuracy: 85.63%
# Epoch [77/500], Step [20/92], Loss: 0.2254, Accuracy: 87.80%
# Epoch [77/500], Step [30/92], Loss: 0.2005, Accuracy: 89.09%
# Epoch [77/500], Step [40/92], Loss: 0.2364, Accuracy: 88.56%
# ...
# Saving weights-->
# Epoch [476/500], Step [10/92], Loss: 0.1321, Accuracy: 90.02%
# Epoch [476/500], Step [20/92], Loss: 0.1819, Accuracy: 87.06%
# Epoch [476/500], Step [30/92], Loss: 0.1733, Accuracy: 87.59%
# Epoch [476/500], Step [40/92], Loss: 0.1318, Accuracy: 90.75%
# Epoch [476/500], Step [50/92], Loss: 0.1954, Accuracy: 86.81%
# Epoch [476/500], Step [60/92], Loss: 0.2041, Accuracy: 86.83%
# Epoch [476/500], Step [70/92], Loss: 0.1794, Accuracy: 87.87%
# Epoch [476/500], Step [80/92], Loss: 0.1320, Accuracy: 89.83%
# Epoch [476/500], Step [90/92], Loss: 0.1561, Accuracy: 88.57%
# Epoch [476/500] Average Loss: 0.1571, Average Accuracy: 89.08%
# Saving weights-->
# Epoch [477/500], Step [10/92], Loss: 0.1596, Accuracy: 88.86%
# Epoch [477/500], Step [20/92], Loss: 0.1686, Accuracy: 88.23%
# Epoch [477/500], Step [30/92], Loss: 0.1594, Accuracy: 89.82%
# Epoch [477/500], Step [40/92], Loss: 0.1845, Accuracy: 87.91%
# Epoch [477/500], Step [50/92], Loss: 0.1485, Accuracy: 90.95%
# Epoch [477/500], Step [60/92], Loss: 0.1423, Accuracy: 89.58%
# Epoch [477/500], Step [70/92], Loss: 0.0977, Accuracy: 93.92%
# Epoch [477/500], Step [80/92], Loss: 0.1481, Accuracy: 89.74%
# Epoch [477/500], Step [90/92], Loss: 0.1469, Accuracy: 90.54%
# Epoch [477/500] Average Loss: 0.1565, Average Accuracy: 89.38%
# Saving weights-->
# Epoch [478/500], Step [10/92], Loss: 0.1339, Accuracy: 90.35%
# Epoch [478/500], Step [20/92], Loss: 0.2176, Accuracy: 84.67%
# Epoch [478/500], Step [30/92], Loss: 0.1295, Accuracy: 91.04%
# Epoch [478/500], Step [40/92], Loss: 0.1632, Accuracy: 90.84%
# Epoch [478/500], Step [50/92], Loss: 0.1794, Accuracy: 87.76%
# Epoch [478/500], Step [60/92], Loss: 0.1454, Accuracy: 90.20%
# Epoch [478/500], Step [70/92], Loss: 0.1376, Accuracy: 90.38%
# Epoch [478/500], Step [80/92], Loss: 0.1616, Accuracy: 88.70%
# Epoch [478/500], Step [90/92], Loss: 0.1260, Accuracy: 91.64%
# Epoch [478/500] Average Loss: 0.1531, Average Accuracy: 89.53%
# Saving weights-->
# Epoch [479/500], Step [10/92], Loss: 0.1045, Accuracy: 92.57%
# Epoch [479/500], Step [20/92], Loss: 0.2024, Accuracy: 84.93%
# Epoch [479/500], Step [30/92], Loss: 0.1450, Accuracy: 89.69%
# Epoch [479/500], Step [40/92], Loss: 0.1395, Accuracy: 90.09%
# Epoch [479/500], Step [50/92], Loss: 0.1403, Accuracy: 90.45%
# Epoch [479/500], Step [60/92], Loss: 0.1288, Accuracy: 90.35%
# Epoch [479/500], Step [70/92], Loss: 0.1478, Accuracy: 89.80%
# Epoch [479/500], Step [80/92], Loss: 0.2325, Accuracy: 87.18%
# Epoch [479/500], Step [90/92], Loss: 0.1614, Accuracy: 89.05%
# Epoch [479/500] Average Loss: 0.1542, Average Accuracy: 89.41%
# Saving weights-->
# Epoch [480/500], Step [10/92], Loss: 0.1482, Accuracy: 89.72%
# Epoch [480/500], Step [20/92], Loss: 0.1479, Accuracy: 89.74%
# Epoch [480/500], Step [30/92], Loss: 0.2046, Accuracy: 86.61%
# Epoch [480/500], Step [40/92], Loss: 0.1919, Accuracy: 87.96%
# Epoch [480/500], Step [50/92], Loss: 0.1608, Accuracy: 90.77%
# Epoch [480/500], Step [60/92], Loss: 0.1449, Accuracy: 90.65%
# Epoch [480/500], Step [70/92], Loss: 0.1411, Accuracy: 90.72%
# Epoch [480/500], Step [80/92], Loss: 0.0899, Accuracy: 94.15%
# Epoch [480/500], Step [90/92], Loss: 0.1566, Accuracy: 88.91%
# Epoch [480/500] Average Loss: 0.1494, Average Accuracy: 89.63%
# Saving weights-->
# Epoch [481/500], Step [10/92], Loss: 0.1105, Accuracy: 91.98%
# Epoch [481/500], Step [20/92], Loss: 0.1829, Accuracy: 86.62%
# Epoch [481/500], Step [30/92], Loss: 0.1377, Accuracy: 90.35%
# Epoch [481/500], Step [40/92], Loss: 0.1393, Accuracy: 89.60%
# Epoch [481/500], Step [50/92], Loss: 0.1455, Accuracy: 89.74%
# Epoch [481/500], Step [60/92], Loss: 0.1278, Accuracy: 90.76%
# Epoch [481/500], Step [70/92], Loss: 0.1010, Accuracy: 92.81%
# Epoch [481/500], Step [80/92], Loss: 0.1764, Accuracy: 87.75%
# Epoch [481/500], Step [90/92], Loss: 0.0687, Accuracy: 95.84%
# Epoch [481/500] Average Loss: 0.1489, Average Accuracy: 89.63%
# Saving weights-->
# Epoch [482/500], Step [10/92], Loss: 0.1499, Accuracy: 89.54%
# Epoch [482/500], Step [20/92], Loss: 0.1432, Accuracy: 90.31%
# Epoch [482/500], Step [30/92], Loss: 0.1676, Accuracy: 89.26%
# Epoch [482/500], Step [40/92], Loss: 0.1951, Accuracy: 87.50%
# Epoch [482/500], Step [50/92], Loss: 0.1230, Accuracy: 91.78%
# Epoch [482/500], Step [60/92], Loss: 0.1625, Accuracy: 88.69%
# Epoch [482/500], Step [70/92], Loss: 0.0995, Accuracy: 93.83%
# Epoch [482/500], Step [80/92], Loss: 0.1857, Accuracy: 88.79%
# Epoch [482/500], Step [90/92], Loss: 0.0799, Accuracy: 95.13%
# Epoch [482/500] Average Loss: 0.1527, Average Accuracy: 89.45%
# Saving weights-->
# Epoch [483/500], Step [10/92], Loss: 0.1932, Accuracy: 86.69%
# Epoch [483/500], Step [20/92], Loss: 0.1331, Accuracy: 89.83%
# Epoch [483/500], Step [30/92], Loss: 0.2035, Accuracy: 86.13%
# Epoch [483/500], Step [40/92], Loss: 0.1533, Accuracy: 90.08%
# Epoch [483/500], Step [50/92], Loss: 0.1284, Accuracy: 90.45%
# Epoch [483/500], Step [60/92], Loss: 0.1202, Accuracy: 92.26%
# Epoch [483/500], Step [70/92], Loss: 0.1109, Accuracy: 92.09%
# Epoch [483/500], Step [80/92], Loss: 0.1739, Accuracy: 87.82%
# Epoch [483/500], Step [90/92], Loss: 0.1406, Accuracy: 91.10%
# Epoch [483/500] Average Loss: 0.1508, Average Accuracy: 89.52%
# Saving weights-->
# Epoch [484/500], Step [10/92], Loss: 0.1535, Accuracy: 89.73%
# Epoch [484/500], Step [20/92], Loss: 0.1312, Accuracy: 90.80%
# Epoch [484/500], Step [30/92], Loss: 0.1772, Accuracy: 88.18%
# Epoch [484/500], Step [40/92], Loss: 0.1109, Accuracy: 92.61%
# Epoch [484/500], Step [50/92], Loss: 0.0735, Accuracy: 95.55%
# Epoch [484/500], Step [60/92], Loss: 0.1024, Accuracy: 92.66%
# Epoch [484/500], Step [70/92], Loss: 0.1646, Accuracy: 89.17%
# Epoch [484/500], Step [80/92], Loss: 0.1859, Accuracy: 86.66%
# Epoch [484/500], Step [90/92], Loss: 0.1791, Accuracy: 87.31%
# Epoch [484/500] Average Loss: 0.1545, Average Accuracy: 89.23%
# Saving weights-->
# Epoch [485/500], Step [10/92], Loss: 0.1412, Accuracy: 89.47%
# Epoch [485/500], Step [20/92], Loss: 0.1666, Accuracy: 89.85%
# Epoch [485/500], Step [30/92], Loss: 0.1464, Accuracy: 89.67%
# Epoch [485/500], Step [40/92], Loss: 0.1056, Accuracy: 92.87%
# Epoch [485/500], Step [50/92], Loss: 0.1527, Accuracy: 90.98%
# Epoch [485/500], Step [60/92], Loss: 0.1924, Accuracy: 88.33%
# Epoch [485/500], Step [70/92], Loss: 0.1789, Accuracy: 88.01%
# Epoch [485/500], Step [80/92], Loss: 0.1520, Accuracy: 89.50%
# Epoch [485/500], Step [90/92], Loss: 0.1832, Accuracy: 86.45%
# Epoch [485/500] Average Loss: 0.1499, Average Accuracy: 89.57%
# Saving weights-->
# Epoch [486/500], Step [10/92], Loss: 0.1524, Accuracy: 89.25%
# Epoch [486/500], Step [20/92], Loss: 0.1273, Accuracy: 91.34%
# Epoch [486/500], Step [30/92], Loss: 0.1690, Accuracy: 87.54%
# Epoch [486/500], Step [40/92], Loss: 0.1362, Accuracy: 90.76%
# Epoch [486/500], Step [50/92], Loss: 0.1473, Accuracy: 89.55%
# Epoch [486/500], Step [60/92], Loss: 0.2048, Accuracy: 88.28%
# Epoch [486/500], Step [70/92], Loss: 0.1765, Accuracy: 87.18%
# Epoch [486/500], Step [80/92], Loss: 0.1894, Accuracy: 86.03%
# Epoch [486/500], Step [90/92], Loss: 0.1766, Accuracy: 87.92%
# Epoch [486/500] Average Loss: 0.1538, Average Accuracy: 89.36%
# Saving weights-->
# Epoch [487/500], Step [10/92], Loss: 0.1624, Accuracy: 88.06%
# Epoch [487/500], Step [20/92], Loss: 0.1613, Accuracy: 88.64%
# Epoch [487/500], Step [30/92], Loss: 0.1396, Accuracy: 90.16%
# Epoch [487/500], Step [40/92], Loss: 0.1140, Accuracy: 91.71%
# Epoch [487/500], Step [50/92], Loss: 0.1562, Accuracy: 89.77%
# Epoch [487/500], Step [60/92], Loss: 0.1428, Accuracy: 89.47%
# Epoch [487/500], Step [70/92], Loss: 0.1470, Accuracy: 90.10%
# Epoch [487/500], Step [80/92], Loss: 0.1505, Accuracy: 89.09%
# Epoch [487/500], Step [90/92], Loss: 0.1073, Accuracy: 92.36%
# Epoch [487/500] Average Loss: 0.1544, Average Accuracy: 89.33%
# Saving weights-->
# Epoch [488/500], Step [10/92], Loss: 0.1334, Accuracy: 90.95%
# Epoch [488/500], Step [20/92], Loss: 0.1553, Accuracy: 89.05%
# Epoch [488/500], Step [30/92], Loss: 0.2229, Accuracy: 87.42%
# Epoch [488/500], Step [40/92], Loss: 0.0868, Accuracy: 94.43%
# Epoch [488/500], Step [50/92], Loss: 0.0750, Accuracy: 95.41%
# Epoch [488/500], Step [60/92], Loss: 0.1754, Accuracy: 87.59%
# Epoch [488/500], Step [70/92], Loss: 0.1929, Accuracy: 86.10%
# Epoch [488/500], Step [80/92], Loss: 0.1611, Accuracy: 88.33%
# Epoch [488/500], Step [90/92], Loss: 0.1232, Accuracy: 91.09%
# Epoch [488/500] Average Loss: 0.1518, Average Accuracy: 89.42%
# Saving weights-->
# Epoch [489/500], Step [10/92], Loss: 0.1607, Accuracy: 88.31%
# Epoch [489/500], Step [20/92], Loss: 0.1225, Accuracy: 91.79%
# Epoch [489/500], Step [30/92], Loss: 0.1408, Accuracy: 90.29%
# Epoch [489/500], Step [40/92], Loss: 0.1263, Accuracy: 90.92%
# Epoch [489/500], Step [50/92], Loss: 0.1276, Accuracy: 91.38%
# Epoch [489/500], Step [60/92], Loss: 0.1285, Accuracy: 90.56%
# Epoch [489/500], Step [70/92], Loss: 0.1242, Accuracy: 91.96%
# Epoch [489/500], Step [80/92], Loss: 0.1630, Accuracy: 88.50%
# Epoch [489/500], Step [90/92], Loss: 0.1421, Accuracy: 89.13%
# Epoch [489/500] Average Loss: 0.1518, Average Accuracy: 89.42%
# Saving weights-->
# Epoch [490/500], Step [10/92], Loss: 0.1506, Accuracy: 88.65%
# Epoch [490/500], Step [20/92], Loss: 0.1557, Accuracy: 88.68%
# Epoch [490/500], Step [30/92], Loss: 0.1266, Accuracy: 90.59%
# Epoch [490/500], Step [40/92], Loss: 0.0687, Accuracy: 95.82%
# Epoch [490/500], Step [50/92], Loss: 0.1329, Accuracy: 90.66%
# Epoch [490/500], Step [60/92], Loss: 0.1767, Accuracy: 87.53%
# Epoch [490/500], Step [70/92], Loss: 0.1192, Accuracy: 91.18%
# Epoch [490/500], Step [80/92], Loss: 0.1516, Accuracy: 89.25%
# Epoch [490/500], Step [90/92], Loss: 0.0981, Accuracy: 92.74%
# Epoch [490/500] Average Loss: 0.1503, Average Accuracy: 89.49%
# Saving weights-->
# Epoch [491/500], Step [10/92], Loss: 0.1470, Accuracy: 88.72%
# Epoch [491/500], Step [20/92], Loss: 0.1723, Accuracy: 88.27%
# Epoch [491/500], Step [30/92], Loss: 0.1035, Accuracy: 94.11%
# Epoch [491/500], Step [40/92], Loss: 0.1243, Accuracy: 91.66%
# Epoch [491/500], Step [50/92], Loss: 0.1522, Accuracy: 88.65%
# Epoch [491/500], Step [60/92], Loss: 0.1358, Accuracy: 90.46%
# Epoch [491/500], Step [70/92], Loss: 0.1419, Accuracy: 89.94%
# Epoch [491/500], Step [80/92], Loss: 0.1425, Accuracy: 89.19%
# Epoch [491/500], Step [90/92], Loss: 0.1922, Accuracy: 86.91%
# Epoch [491/500] Average Loss: 0.1526, Average Accuracy: 89.42%
# Saving weights-->
# Epoch [492/500], Step [10/92], Loss: 0.2081, Accuracy: 85.96%
# Epoch [492/500], Step [20/92], Loss: 0.1634, Accuracy: 88.46%
# Epoch [492/500], Step [30/92], Loss: 0.1856, Accuracy: 87.61%
# Epoch [492/500], Step [40/92], Loss: 0.1597, Accuracy: 88.72%
# Epoch [492/500], Step [50/92], Loss: 0.1981, Accuracy: 85.97%
# Epoch [492/500], Step [60/92], Loss: 0.1594, Accuracy: 89.14%
# Epoch [492/500], Step [70/92], Loss: 0.2514, Accuracy: 82.08%
# Epoch [492/500], Step [80/92], Loss: 0.1596, Accuracy: 88.35%
# Epoch [492/500], Step [90/92], Loss: 0.0823, Accuracy: 95.27%
# Epoch [492/500] Average Loss: 0.1556, Average Accuracy: 89.26%
# Saving weights-->
# Epoch [493/500], Step [10/92], Loss: 0.0709, Accuracy: 95.55%
# Epoch [493/500], Step [20/92], Loss: 0.1917, Accuracy: 86.35%
# Epoch [493/500], Step [30/92], Loss: 0.1533, Accuracy: 89.57%
# Epoch [493/500], Step [40/92], Loss: 0.1739, Accuracy: 88.86%
# Epoch [493/500], Step [50/92], Loss: 0.1647, Accuracy: 88.43%
# Epoch [493/500], Step [60/92], Loss: 0.2019, Accuracy: 85.44%
# Epoch [493/500], Step [70/92], Loss: 0.1105, Accuracy: 91.72%
# Epoch [493/500], Step [80/92], Loss: 0.1290, Accuracy: 91.11%
# Epoch [493/500], Step [90/92], Loss: 0.1992, Accuracy: 87.31%
# Epoch [493/500] Average Loss: 0.1563, Average Accuracy: 89.24%
# Saving weights-->
# Epoch [494/500], Step [10/92], Loss: 0.0622, Accuracy: 95.82%
# Epoch [494/500], Step [20/92], Loss: 0.1335, Accuracy: 90.60%
# Epoch [494/500], Step [30/92], Loss: 0.1214, Accuracy: 91.46%
# Epoch [494/500], Step [40/92], Loss: 0.1502, Accuracy: 89.31%
# Epoch [494/500], Step [50/92], Loss: 0.1543, Accuracy: 89.51%
# Epoch [494/500], Step [60/92], Loss: 0.1228, Accuracy: 91.35%
# Epoch [494/500], Step [70/92], Loss: 0.1318, Accuracy: 90.95%
# Epoch [494/500], Step [80/92], Loss: 0.0802, Accuracy: 95.24%
# Epoch [494/500], Step [90/92], Loss: 0.1434, Accuracy: 89.56%
# Epoch [494/500] Average Loss: 0.1533, Average Accuracy: 89.49%
# Saving weights-->
# Epoch [495/500], Step [10/92], Loss: 0.1508, Accuracy: 90.04%
# Epoch [495/500], Step [20/92], Loss: 0.2214, Accuracy: 86.45%
# Epoch [495/500], Step [30/92], Loss: 0.0914, Accuracy: 94.10%
# Epoch [495/500], Step [40/92], Loss: 0.1498, Accuracy: 88.74%
# Epoch [495/500], Step [50/92], Loss: 0.0851, Accuracy: 94.79%
# Epoch [495/500], Step [60/92], Loss: 0.1078, Accuracy: 91.98%
# Epoch [495/500], Step [70/92], Loss: 0.0954, Accuracy: 93.01%
# Epoch [495/500], Step [80/92], Loss: 0.1802, Accuracy: 86.67%
# Epoch [495/500], Step [90/92], Loss: 0.1636, Accuracy: 87.85%
# Epoch [495/500] Average Loss: 0.1533, Average Accuracy: 89.32%
# Saving weights-->
# Epoch [496/500], Step [10/92], Loss: 0.2095, Accuracy: 86.67%
# Epoch [496/500], Step [20/92], Loss: 0.1490, Accuracy: 89.74%
# Epoch [496/500], Step [30/92], Loss: 0.1383, Accuracy: 90.32%
# Epoch [496/500], Step [40/92], Loss: 0.1721, Accuracy: 87.30%
# Epoch [496/500], Step [50/92], Loss: 0.1778, Accuracy: 88.22%
# Epoch [496/500], Step [60/92], Loss: 0.1584, Accuracy: 89.21%
# Epoch [496/500], Step [70/92], Loss: 0.2007, Accuracy: 86.00%
# Epoch [496/500], Step [80/92], Loss: 0.0767, Accuracy: 95.11%
# Epoch [496/500], Step [90/92], Loss: 0.1670, Accuracy: 89.63%
# Epoch [496/500] Average Loss: 0.1488, Average Accuracy: 89.65%
# Saving weights-->
# Epoch [497/500], Step [10/92], Loss: 0.1477, Accuracy: 89.57%
# Epoch [497/500], Step [20/92], Loss: 0.1443, Accuracy: 89.86%
# Epoch [497/500], Step [30/92], Loss: 0.0983, Accuracy: 93.03%
# Epoch [497/500], Step [40/92], Loss: 0.1670, Accuracy: 87.95%
# Epoch [497/500], Step [50/92], Loss: 0.1162, Accuracy: 91.95%
# Epoch [497/500], Step [60/92], Loss: 0.2006, Accuracy: 86.23%
# Epoch [497/500], Step [70/92], Loss: 0.1272, Accuracy: 91.12%
# Epoch [497/500], Step [80/92], Loss: 0.1432, Accuracy: 88.96%
# Epoch [497/500], Step [90/92], Loss: 0.1227, Accuracy: 90.97%
# Epoch [497/500] Average Loss: 0.1513, Average Accuracy: 89.37%
# Saving weights-->
# Epoch [498/500], Step [10/92], Loss: 0.1209, Accuracy: 90.78%
# Epoch [498/500], Step [20/92], Loss: 0.1696, Accuracy: 86.78%
# Epoch [498/500], Step [30/92], Loss: 0.1131, Accuracy: 91.73%
# Epoch [498/500], Step [40/92], Loss: 0.1455, Accuracy: 89.95%
# Epoch [498/500], Step [50/92], Loss: 0.1236, Accuracy: 91.38%
# Epoch [498/500], Step [60/92], Loss: 0.1326, Accuracy: 90.36%
# Epoch [498/500], Step [70/92], Loss: 0.1578, Accuracy: 89.14%
# Epoch [498/500], Step [80/92], Loss: 0.1605, Accuracy: 88.44%
# Epoch [498/500], Step [90/92], Loss: 0.1624, Accuracy: 88.38%
# Epoch [498/500] Average Loss: 0.1527, Average Accuracy: 89.36%
# Saving weights-->
# Epoch [499/500], Step [10/92], Loss: 0.1792, Accuracy: 86.68%
# Epoch [499/500], Step [20/92], Loss: 0.0999, Accuracy: 92.80%
# Epoch [499/500], Step [30/92], Loss: 0.1315, Accuracy: 90.04%
# Epoch [499/500], Step [40/92], Loss: 0.1153, Accuracy: 91.95%
# Epoch [499/500], Step [50/92], Loss: 0.1756, Accuracy: 87.65%
# Epoch [499/500], Step [60/92], Loss: 0.1441, Accuracy: 89.55%
# Epoch [499/500], Step [70/92], Loss: 0.1180, Accuracy: 91.57%
# Epoch [499/500], Step [80/92], Loss: 0.1631, Accuracy: 88.38%
# Epoch [499/500], Step [90/92], Loss: 0.1514, Accuracy: 89.41%
# Epoch [499/500] Average Loss: 0.1503, Average Accuracy: 89.52%
# Saving weights-->
# Epoch [500/500], Step [10/92], Loss: 0.1588, Accuracy: 88.68%
# Epoch [500/500], Step [20/92], Loss: 0.1375, Accuracy: 90.13%
# Epoch [500/500], Step [30/92], Loss: 0.1989, Accuracy: 85.50%
# Epoch [500/500], Step [40/92], Loss: 0.1812, Accuracy: 88.71%
# Epoch [500/500], Step [50/92], Loss: 0.1746, Accuracy: 87.56%
# Epoch [500/500], Step [60/92], Loss: 0.2135, Accuracy: 84.71%
# Epoch [500/500], Step [70/92], Loss: 0.1793, Accuracy: 86.82%
# Epoch [500/500], Step [80/92], Loss: 0.1356, Accuracy: 90.14%
# Epoch [500/500], Step [90/92], Loss: 0.1707, Accuracy: 87.69%
# Epoch [500/500] Average Loss: 0.1507, Average Accuracy: 89.46%
# Saving weights-->

# %%
save_checkpoint({'state_dict': model.state_dict(), 'optimizer': optimizer.state_dict()})
# Out:
# Saving weights-->

# %% [markdown]
# ## NOW lets see the performance on the data loader

# %%
def evaluate_model(model, data_loader, vocab):
    model.eval()
    total_accuracy = 0
    num_batches = 0
    
    #close the grad to avoid crach and accumilation of memory
    with torch.no_grad():
        for src, tgt in data_loader:
            src, tgt = src.to(device), tgt.to(device)
            output = model(src, tgt[:, :-1])
            
            accuracy = check_accuracy(output.view(-1, len(vocab)), tgt[:, 1:].reshape(-1))
            total_accuracy += accuracy
            num_batches += 1
    
    # Avg. accuracy
    return total_accuracy / num_batches

# %% [markdown]
# ## And of course this is not the best test accuarcy but it is fine for my epochs and dataset size used and of couse my architecture

# %%
# Evaluate on the test set
test_accuracy = evaluate_model(model, test_loader, vocab)
print(f"Test Accuracy: {test_accuracy:.2f}%")
# Out:
# Test Accuracy: 57.11%
